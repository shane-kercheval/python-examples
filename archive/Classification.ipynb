# %%
import helpsk as hlp
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_openml
import seaborn as sns

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder  # , LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
# from sklearn.base import BaseEstimator, TransformerMixin

# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
#https://www.openml.org/d/31
credit_g = fetch_openml('credit-g', version=1)
credit_data = credit_g['data']
credit_data['target'] = credit_g['target']
print(credit_data.shape)

del credit_g
# Out:
# (1000, 21)

# %%
## Create Missing Values
credit_data['duration'].iloc[0:46] = np.nan
credit_data['checking_status'].iloc[25:75] = np.nan
credit_data['credit_amount'].iloc[10:54] = 0
# Out:
# /Users/shanekercheval/opt/anaconda3/envs/python-examples/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
hlp.pandas.numeric_summary(credit_data, return_style=True)
# Out:
# <style type="text/css">
# #T_374ec_row0_col1, #T_374ec_row1_col3 {
#   background-color: #EBB13E;
# }
# #T_374ec_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#CF3721 5.0%, transparent 5.0%);
# }
# #T_374ec_row0_col4, #T_374ec_row1_col2, #T_374ec_row2_col2, #T_374ec_row2_col4, #T_374ec_row3_col2, #T_374ec_row3_col4, #T_374ec_row4_col2, #T_374ec_row4_col4, #T_374ec_row5_col2, #T_374ec_row5_col4, #T_374ec_row6_col2, #T_374ec_row6_col4 {
#   width: 10em;
#   height: 80%;
# }
# #T_374ec_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 57.0%, transparent 57.0%);
# }
# #T_374ec_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 77.5%, transparent 77.5%);
# }
# #T_374ec_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 4.0%, transparent 4.0%);
# }
# #T_374ec_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 91.0%, transparent 91.0%);
# }
# #T_374ec_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 98.0%, transparent 98.0%);
# }
# #T_374ec_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 38.0%, transparent 38.0%);
# }
# #T_374ec_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.7%, #B4B7B9 36.7%, #B4B7B9 50.0%, transparent 50.0%);
# }
# #T_374ec_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 39.0%, transparent 39.0%);
# }
# #T_374ec_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 43.2%, #B4B7B9 43.2%, #B4B7B9 50.0%, transparent 50.0%);
# }
# #T_374ec_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 32.0%, transparent 32.0%);
# }
# #T_374ec_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 75.5%, transparent 75.5%);
# }
# #T_374ec_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 41.0%, transparent 41.0%);
# }
# #T_374ec_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 81.7%, transparent 81.7%);
# }
# #T_374ec_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 31.0%, transparent 31.0%);
# }
# #T_374ec_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 97.7%, transparent 97.7%);
# }
# </style>
# <table id="T_374ec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" ># of Non-Nulls</th>
#       <th class="col_heading level0 col1" ># of Nulls</th>
#       <th class="col_heading level0 col2" >% Nulls</th>
#       <th class="col_heading level0 col3" ># of Zeros</th>
#       <th class="col_heading level0 col4" >% Zeros</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >St Dev.</th>
#       <th class="col_heading level0 col7" >Coef of Var</th>
#       <th class="col_heading level0 col8" >Skewness</th>
#       <th class="col_heading level0 col9" >Kurtosis</th>
#       <th class="col_heading level0 col10" >Min</th>
#       <th class="col_heading level0 col11" >10%</th>
#       <th class="col_heading level0 col12" >25%</th>
#       <th class="col_heading level0 col13" >50%</th>
#       <th class="col_heading level0 col14" >75%</th>
#       <th class="col_heading level0 col15" >90%</th>
#       <th class="col_heading level0 col16" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_374ec_level0_row0" class="row_heading level0 row0" >duration</th>
#       <td id="T_374ec_row0_col0" class="data row0 col0" >954</td>
#       <td id="T_374ec_row0_col1" class="data row0 col1" >46</td>
#       <td id="T_374ec_row0_col2" class="data row0 col2" >5.0%</td>
#       <td id="T_374ec_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_374ec_row0_col4" class="data row0 col4" >0.0%</td>
#       <td id="T_374ec_row0_col5" class="data row0 col5" >20.9</td>
#       <td id="T_374ec_row0_col6" class="data row0 col6" >12.0</td>
#       <td id="T_374ec_row0_col7" class="data row0 col7" >0.6</td>
#       <td id="T_374ec_row0_col8" class="data row0 col8" >1.1</td>
#       <td id="T_374ec_row0_col9" class="data row0 col9" >1.0</td>
#       <td id="T_374ec_row0_col10" class="data row0 col10" >4.0</td>
#       <td id="T_374ec_row0_col11" class="data row0 col11" >9.0</td>
#       <td id="T_374ec_row0_col12" class="data row0 col12" >12.0</td>
#       <td id="T_374ec_row0_col13" class="data row0 col13" >18.0</td>
#       <td id="T_374ec_row0_col14" class="data row0 col14" >24.0</td>
#       <td id="T_374ec_row0_col15" class="data row0 col15" >36.0</td>
#       <td id="T_374ec_row0_col16" class="data row0 col16" >72.0</td>
#     </tr>
#     <tr>
#       <th id="T_374ec_level0_row1" class="row_heading level0 row1" >credit_amount</th>
#       <td id="T_374ec_row1_col0" class="data row1 col0" >1,000</td>
#       <td id="T_374ec_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_374ec_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_374ec_row1_col3" class="data row1 col3" >44</td>
#       <td id="T_374ec_row1_col4" class="data row1 col4" >4.0%</td>
#       <td id="T_374ec_row1_col5" class="data row1 col5" >3,132.9</td>
#       <td id="T_374ec_row1_col6" class="data row1 col6" >2,853.4</td>
#       <td id="T_374ec_row1_col7" class="data row1 col7" >0.9</td>
#       <td id="T_374ec_row1_col8" class="data row1 col8" >1.9</td>
#       <td id="T_374ec_row1_col9" class="data row1 col9" >4.3</td>
#       <td id="T_374ec_row1_col10" class="data row1 col10" >0.0</td>
#       <td id="T_374ec_row1_col11" class="data row1 col11" >740.0</td>
#       <td id="T_374ec_row1_col12" class="data row1 col12" >1,287.8</td>
#       <td id="T_374ec_row1_col13" class="data row1 col13" >2,224.0</td>
#       <td id="T_374ec_row1_col14" class="data row1 col14" >3,873.5</td>
#       <td id="T_374ec_row1_col15" class="data row1 col15" >7,119.8</td>
#       <td id="T_374ec_row1_col16" class="data row1 col16" >18,424.0</td>
#     </tr>
#     <tr>
#       <th id="T_374ec_level0_row2" class="row_heading level0 row2" >installment_commitment</th>
#       <td id="T_374ec_row2_col0" class="data row2 col0" >1,000</td>
#       <td id="T_374ec_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_374ec_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_374ec_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_374ec_row2_col4" class="data row2 col4" >0.0%</td>
#       <td id="T_374ec_row2_col5" class="data row2 col5" >3.0</td>
#       <td id="T_374ec_row2_col6" class="data row2 col6" >1.1</td>
#       <td id="T_374ec_row2_col7" class="data row2 col7" >0.4</td>
#       <td id="T_374ec_row2_col8" class="data row2 col8" >-0.5</td>
#       <td id="T_374ec_row2_col9" class="data row2 col9" >-1.2</td>
#       <td id="T_374ec_row2_col10" class="data row2 col10" >1.0</td>
#       <td id="T_374ec_row2_col11" class="data row2 col11" >1.0</td>
#       <td id="T_374ec_row2_col12" class="data row2 col12" >2.0</td>
#       <td id="T_374ec_row2_col13" class="data row2 col13" >3.0</td>
#       <td id="T_374ec_row2_col14" class="data row2 col14" >4.0</td>
#       <td id="T_374ec_row2_col15" class="data row2 col15" >4.0</td>
#       <td id="T_374ec_row2_col16" class="data row2 col16" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_374ec_level0_row3" class="row_heading level0 row3" >residence_since</th>
#       <td id="T_374ec_row3_col0" class="data row3 col0" >1,000</td>
#       <td id="T_374ec_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_374ec_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_374ec_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_374ec_row3_col4" class="data row3 col4" >0.0%</td>
#       <td id="T_374ec_row3_col5" class="data row3 col5" >2.9</td>
#       <td id="T_374ec_row3_col6" class="data row3 col6" >1.1</td>

# %%
hlp.pandas.non_numeric_summary(credit_data, return_style=True)
# Out:
# <style type="text/css">
# #T_7b435_row0_col1 {
#   background-color: #EBB13E;
# }
# #T_7b435_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#CF3721 5.0%, transparent 5.0%);
# }
# #T_7b435_row0_col5, #T_7b435_row5_col5, #T_7b435_row7_col5, #T_7b435_row10_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.4%, transparent 0.4%);
# }
# #T_7b435_row1_col2, #T_7b435_row2_col2, #T_7b435_row3_col2, #T_7b435_row4_col2, #T_7b435_row5_col2, #T_7b435_row6_col2, #T_7b435_row7_col2, #T_7b435_row8_col2, #T_7b435_row9_col2, #T_7b435_row10_col2, #T_7b435_row11_col2, #T_7b435_row12_col2, #T_7b435_row13_col2 {
#   width: 10em;
#   height: 80%;
# }
# #T_7b435_row1_col5, #T_7b435_row3_col5, #T_7b435_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.5%, transparent 0.5%);
# }
# #T_7b435_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 1.0%, transparent 1.0%);
# }
# #T_7b435_row6_col5, #T_7b435_row8_col5, #T_7b435_row9_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.3%, transparent 0.3%);
# }
# #T_7b435_row11_col5, #T_7b435_row12_col5, #T_7b435_row13_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.2%, transparent 0.2%);
# }
# </style>
# <table id="T_7b435_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" ># of Non-Nulls</th>
#       <th class="col_heading level0 col1" ># of Nulls</th>
#       <th class="col_heading level0 col2" >% Nulls</th>
#       <th class="col_heading level0 col3" >Most Freq. Value</th>
#       <th class="col_heading level0 col4" ># of Unique</th>
#       <th class="col_heading level0 col5" >% Unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b435_level0_row0" class="row_heading level0 row0" >checking_status</th>
#       <td id="T_7b435_row0_col0" class="data row0 col0" >950</td>
#       <td id="T_7b435_row0_col1" class="data row0 col1" >50</td>
#       <td id="T_7b435_row0_col2" class="data row0 col2" >5.0%</td>
#       <td id="T_7b435_row0_col3" class="data row0 col3" >no checking</td>
#       <td id="T_7b435_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_7b435_row0_col5" class="data row0 col5" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row1" class="row_heading level0 row1" >credit_history</th>
#       <td id="T_7b435_row1_col0" class="data row1 col0" >1,000</td>
#       <td id="T_7b435_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_7b435_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_7b435_row1_col3" class="data row1 col3" >existing paid</td>
#       <td id="T_7b435_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_7b435_row1_col5" class="data row1 col5" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row2" class="row_heading level0 row2" >purpose</th>
#       <td id="T_7b435_row2_col0" class="data row2 col0" >1,000</td>
#       <td id="T_7b435_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_7b435_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_7b435_row2_col3" class="data row2 col3" >radio/tv</td>
#       <td id="T_7b435_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_7b435_row2_col5" class="data row2 col5" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row3" class="row_heading level0 row3" >savings_status</th>
#       <td id="T_7b435_row3_col0" class="data row3 col0" >1,000</td>
#       <td id="T_7b435_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_7b435_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_7b435_row3_col3" class="data row3 col3" >&lt;100</td>
#       <td id="T_7b435_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_7b435_row3_col5" class="data row3 col5" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row4" class="row_heading level0 row4" >employment</th>
#       <td id="T_7b435_row4_col0" class="data row4 col0" >1,000</td>
#       <td id="T_7b435_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_7b435_row4_col2" class="data row4 col2" >0.0%</td>
#       <td id="T_7b435_row4_col3" class="data row4 col3" >1&lt;=X&lt;4</td>
#       <td id="T_7b435_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_7b435_row4_col5" class="data row4 col5" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row5" class="row_heading level0 row5" >personal_status</th>
#       <td id="T_7b435_row5_col0" class="data row5 col0" >1,000</td>
#       <td id="T_7b435_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_7b435_row5_col2" class="data row5 col2" >0.0%</td>
#       <td id="T_7b435_row5_col3" class="data row5 col3" >male single</td>
#       <td id="T_7b435_row5_col4" class="data row5 col4" >4</td>
#       <td id="T_7b435_row5_col5" class="data row5 col5" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row6" class="row_heading level0 row6" >other_parties</th>
#       <td id="T_7b435_row6_col0" class="data row6 col0" >1,000</td>
#       <td id="T_7b435_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_7b435_row6_col2" class="data row6 col2" >0.0%</td>
#       <td id="T_7b435_row6_col3" class="data row6 col3" >none</td>
#       <td id="T_7b435_row6_col4" class="data row6 col4" >3</td>
#       <td id="T_7b435_row6_col5" class="data row6 col5" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row7" class="row_heading level0 row7" >property_magnitude</th>
#       <td id="T_7b435_row7_col0" class="data row7 col0" >1,000</td>
#       <td id="T_7b435_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_7b435_row7_col2" class="data row7 col2" >0.0%</td>
#       <td id="T_7b435_row7_col3" class="data row7 col3" >car</td>
#       <td id="T_7b435_row7_col4" class="data row7 col4" >4</td>
#       <td id="T_7b435_row7_col5" class="data row7 col5" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row8" class="row_heading level0 row8" >other_payment_plans</th>
#       <td id="T_7b435_row8_col0" class="data row8 col0" >1,000</td>
#       <td id="T_7b435_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_7b435_row8_col2" class="data row8 col2" >0.0%</td>
#       <td id="T_7b435_row8_col3" class="data row8 col3" >none</td>
#       <td id="T_7b435_row8_col4" class="data row8 col4" >3</td>
#       <td id="T_7b435_row8_col5" class="data row8 col5" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row9" class="row_heading level0 row9" >housing</th>
#       <td id="T_7b435_row9_col0" class="data row9 col0" >1,000</td>
#       <td id="T_7b435_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_7b435_row9_col2" class="data row9 col2" >0.0%</td>
#       <td id="T_7b435_row9_col3" class="data row9 col3" >own</td>
#       <td id="T_7b435_row9_col4" class="data row9 col4" >3</td>
#       <td id="T_7b435_row9_col5" class="data row9 col5" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row10" class="row_heading level0 row10" >job</th>
#       <td id="T_7b435_row10_col0" class="data row10 col0" >1,000</td>
#       <td id="T_7b435_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_7b435_row10_col2" class="data row10 col2" >0.0%</td>
#       <td id="T_7b435_row10_col3" class="data row10 col3" >skilled</td>
#       <td id="T_7b435_row10_col4" class="data row10 col4" >4</td>
#       <td id="T_7b435_row10_col5" class="data row10 col5" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row11" class="row_heading level0 row11" >own_telephone</th>
#       <td id="T_7b435_row11_col0" class="data row11 col0" >1,000</td>
#       <td id="T_7b435_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_7b435_row11_col2" class="data row11 col2" >0.0%</td>
#       <td id="T_7b435_row11_col3" class="data row11 col3" >none</td>
#       <td id="T_7b435_row11_col4" class="data row11 col4" >2</td>
#       <td id="T_7b435_row11_col5" class="data row11 col5" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7b435_level0_row12" class="row_heading level0 row12" >foreign_worker</th>
#       <td id="T_7b435_row12_col0

# %% [markdown]
# # Training and Test Data

# %%
y_full = credit_data['target']
X_full = credit_data.drop(columns='target')

del credit_data

# %%
hlp.pandas.value_frequency(series=y_full)
# Out:
#       Frequency  Percent
# good        700      0.7
# bad         300      0.3

# %%
y_full[0:10]
# Out:
# 0    good
# 1     bad
# 2    good
# 3    good
# 4     bad
# 5    good
# 6    good
# 7    good
# 8    good
# 9     bad
# Name: target, dtype: category
# Categories (2, object): ['good', 'bad']

# %%
from sklearn.preprocessing import label_binarize
y_full = label_binarize(y_full, classes=['bad', 'good']).flatten()

# %%
y_full[0:10]
# Out:
# array([1, 0, 1, 1, 0, 1, 1, 1, 1, 0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_full, y_full, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(len(y_train))

print(X_test.shape)
print(len(y_test))
# Out:
# (800, 20)
# 800
# (200, 20)
# 200

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([241, 559]))

# %%
np.unique(y_train, return_counts=True)[1] / np.sum(np.unique(y_train, return_counts=True)[1])
# Out:
# array([0.30125, 0.69875])

# %%
np.unique(y_test, return_counts=True)[1] / np.sum(np.unique(y_test, return_counts=True)[1])
# Out:
# array([0.295, 0.705])

# %% [markdown]
# # Transformation Pipeline

# %%
from sklearn.preprocessing import OrdinalEncoder
OrdinalEncoder().fit_transform(X_train[['purpose', 'savings_status']])
# Out:
# array([[0., 2.],
#        [2., 2.],
#        [9., 1.],
#        ...,
#        [9., 3.],
#        [6., 4.],
#        [6., 2.]])

# %%
numeric_columns = hlp.pandas.get_numeric_columns(X_train)
non_numeric_columns = hlp.pandas.get_non_numeric_columns(X_train)
print(numeric_columns)
print(non_numeric_columns)
# Out:
# ['duration', 'credit_amount', 'installment_commitment', 'residence_since', 'age', 'existing_credits', 'num_dependents']
# ['checking_status', 'credit_history', 'purpose', 'savings_status', 'employment', 'personal_status', 'other_parties', 'property_magnitude', 'other_payment_plans', 'housing', 'job', 'own_telephone', 'foreign_worker']

# %%
numeric_pipeline = Pipeline([
    #tune whether or not we want to impute or simply remove rows with missing values
    ('impute', hlp.sklearn_pipeline.TransformerChooser()),
    # this is here so that we can select between MinMax and Scaler
    # if this pipeline is ran in a context outside of tuning, no transformation will take place
    ('scaling', hlp.sklearn_pipeline.TransformerChooser()),
])

# %%
non_numeric_pipeline = Pipeline([
    ('encoder', hlp.sklearn_pipeline.TransformerChooser()),
])

# %%
from sklearn.compose import ColumnTransformer
transformations_pipeline = ColumnTransformer([
    ('numeric', numeric_pipeline, numeric_columns),
    ('non_numeric', non_numeric_pipeline, non_numeric_columns)
])

# %% [markdown]
# # Model

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier(random_state=42)

# %%
full_pipeline = Pipeline([
    ('prep', transformations_pipeline),
    ('model', random_forest_model)
])

# %%
# Show the levels of pipelines/transformers/model
full_pipeline.named_steps
# Out:
# {'prep': ColumnTransformer(transformers=[('numeric',
#                                   Pipeline(steps=[('impute',
#                                                    TransformerChooser()),
#                                                   ('scaling',
#                                                    TransformerChooser())]),
#                                   ['duration', 'credit_amount',
#                                    'installment_commitment', 'residence_since',
#                                    'age', 'existing_credits',
#                                    'num_dependents']),
#                                  ('non_numeric',
#                                   Pipeline(steps=[('encoder',
#                                                    TransformerChooser())]),
#                                   ['checking_status', 'credit_history',
#                                    'purpose', 'savings_status', 'employment',
#                                    'personal_status', 'other_parties',
#                                    'property_magnitude', 'other_payment_plans',
#                                    'housing', 'job', 'own_telephone',
#                                    'foreign_worker'])]),
#  'model': RandomForestClassifier(random_state=42)}

# %% [markdown]
# # Grid Search

# %%
param_grad = [
    {
        'prep__numeric__impute__transformer': [SimpleImputer(strategy='mean')],
        'prep__numeric__scaling__transformer': [MinMaxScaler(), StandardScaler()],
        'prep__non_numeric__encoder__transformer': [OneHotEncoder(),
                                                    hlp.sklearn_pipeline.CustomOrdinalEncoder()],
        'model__max_features': [2, 10, 'auto'],
        'model__n_estimators': [50, 100, 500]
    },
]

# %%
from sklearn.metrics import make_scorer, f1_score, precision_score, recall_score  # , roc_auc_score
from sklearn.metrics import SCORERS

# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html
# https://stackoverflow.com/questions/60615281/different-result-roc-auc-score-and-plot-roc-curve
scores = {
    # https://github.com/scikit-learn/scikit-learn/blob/2beed5584/sklearn/metrics/_scorer.py#L537
    'ROC/AUC':  SCORERS['roc_auc'],
    'F1': make_scorer(f1_score, greater_is_better=True),
    'Pos. Pred. Val': make_scorer(precision_score, greater_is_better=True),
    'True Pos. Rate': make_scorer(recall_score, greater_is_better=True),
}

# %%
num_folds = 5
num_repeats = 2

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
grid_search = GridSearchCV(full_pipeline,
                           param_grid=param_grad,
                           cv=RepeatedKFold(n_splits=num_folds,
                                            n_repeats=num_repeats,
                                            random_state=2),
                           scoring=scores,
                           refit='ROC/AUC',
                           #scoring='roc_auc',
                           return_train_score=True
                          )
grid_search.fit(X_train, y_train)

del param_grad

# %% [markdown]
# ## Results

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.771524602897316
# {'model__max_features': 2, 'model__n_estimators': 500, 'prep__non_numeric__encoder__transformer': OneHotEncoder(), 'prep__numeric__impute__transformer': SimpleImputer(), 'prep__numeric__scaling__transformer': MinMaxScaler()}

# %%
new_param_column_names = {'model | max_features': 'max_features',
                          'model | n_estimators': 'n_estimators',
                          'prep | non_numeric | encoder | transformer': 'encoder',
                          'prep | numeric | impute | transformer': 'imputer',
                          'prep | numeric | scaling | transformer': 'scaler'}

# %%
grid_search_parsed = hlp.sklearn_eval.SearchCVParser(searcher=grid_search,
                                                     higher_score_is_better = True,
                                                     new_param_column_names=new_param_column_names)
grid_search_parsed.results
# Out:
#     ROC/AUC Mean  ROC/AUC 95CI.LO  ROC/AUC 95CI.HI  ROC/AUC Training Mean  \
# 8       0.771525         0.746845         0.796205                    1.0
# 9       0.770846         0.746075         0.795617                    1.0
# 10      0.770301         0.744850         0.795753                    1.0
# 11      0.769573         0.744276         0.794869                    1.0
# 32      0.768572         0.743382         0.793762                    1.0
# 33      0.767877         0.742232         0.793521                    1.0
# 20      0.767023         0.736836         0.797211                    1.0
# 21      0.766990         0.736360         0.797620                    1.0
# 6       0.766777         0.748160         0.785393                    1.0
# 7       0.765756         0.747317         0.784195                    1.0
# 17      0.764853         0.733740         0.795967                    1.0
# 28      0.764688         0.739374         0.790003                    1.0
# 16      0.764325         0.732919         0.795731                    1.0
# 29      0.764130         0.738549         0.789710                    1.0
# 34      0.763058         0.738258         0.787857                    1.0
# 35      0.762838         0.737568         0.788108                    1.0
# 24      0.760620         0.740551         0.780689                    1.0
# 25      0.759543         0.739025         0.780061                    1.0
# 13      0.759017         0.727138         0.790896                    1.0
# 12      0.758956         0.727108         0.790804                    1.0
# 4       0.758269         0.732136         0.784402                    1.0
# 5       0.758003         0.731985         0.784021                    1.0
# 2       0.753837         0.739269         0.768405                    1.0
# 3       0.753530         0.739569         0.767491                    1.0
# 0       0.751019         0.722414         0.779624                    1.0
# 23      0.750880         0.724188         0.777572                    1.0
# 22      0.750814         0.724120         0.777508                    1.0
# 1       0.750629         0.721404         0.779854                    1.0
# 31      0.750543         0.727326         0.773761                    1.0
# 30      0.750269         0.726881         0.773657                    1.0
# 18      0.747343         0.721609         0.773077                    1.0
# 19      0.747264         0.721166         0.773361                    1.0
# 14      0.745538         0.720229         0.770847                    1.0
# 15      0.745164         0.719222         0.771107                    1.0
# 27      0.744034         0.723679         0.764389                    1.0
# 26      0.743588         0.722449         0.764727                    1.0
#
#      F1 Mean  F1 95CI.LO  F1 95CI.HI  F1 Training Mean  Pos. Pred. Val Mean  \
# 8   0.841326    0.826073    0.856580          1.000000             0.748844
# 9   0.841917    0.826357    0.857477          1.000000             0.748645
# 10  0.836300    0.823949    0.848651          1.000000             0.757175
# 11  0.836502    0.824105    0.848898          1.000000             0.758026
# 32  0.836024    0.823770    0.848278          1.000000             0.769569
# 33  0.834623    0.821827    0.847420          1.000000             0.769131
# 20  0.836953    0.821459    0.852448          1.000000             0.774852
# 21  0.837581    0.822185    0.852978          1.000000             0.774595
# 6   0.834036    0.820806    0.847265          1.000000             0.758788
# 7   0.829911    0.816681    0.843140          1.000000             0.756770
# 17  0.832979    0.821040    0.844917          1.000000             0.773677
# 28  0.834629    0.823011    0.846248          1.000000             0.768911
# 16  0.833495    0.820703    0.846286          1.000000             0.773958
# 29  0.833862    0.822044    0.845680          1.000000             0.768136
# 34  0.828897    0.818369    0.839425          1.000000             0.766091
# 35  0.828883    0.818424    0.839341          1.000000             0.766084
# 24  0.836748    0.822076    0.851421          0.999774             0.772022
# 25  0.835107    0.820891    0.849322          0.999774             0.770494
# 13  0.831580    0.821124    0.842037          0.999774             0.776291
# 12  0.831747    0.821353    0.842140          0.999774             0.775904
# 4   0.838330    0.827076    0.849584          1.000000             0.751020
# 5   0.836640    0.825198    0.848083          1.000000             0.749973
# 2   0.826534    0.813479    0.839590          0.999774             0.758762
# 3   0.825206    0.812672    0.837740          0.999774             0.759817
# 0   0.834084    0.817829    0.850340          1.000000             0.752108
# 23  0.815644    0.801192    0.830095          1.000000             0.770052
# 22  0.816940    0.802735    0.831144          1.000000             0.770862
# 1   0.834410    0.818075    0.850746          1.000000             0.752595
# 31  0.821094    0.810000    0.832187          1.000000             0.763457
# 30  0.818846    0.808694    0.828997          1.000000             0.762276
# 18  0.811863    0.799727    0.824000          1.000000             0.768073
# 19  0.813334    0.801854    0.824814          1.000000             0.768489
# 14  0.813893    0.799310    0.828477          0.999778             0.774513
# 15  0.814375    0.799748    0.829003          0.999778             0.774665
# 27  0.820621    0.809256    0.831986          0.999778             0.771251
# 26  0.822803    0.812015    0.833591          0.999778             0.773101
#
#     Pos. Pred. Val 95CI.LO  ...  Pos. Pred. Val Training Mean  \
# 8                 0.722270  ...                      1.000000
# 9                 0.722189  ...                      1.000000
# 10                0.732377  ...                      1.000000
# 11                0.733705  ...                      1.000000
# 32                0.745503  ...                      1.000000
# 33                0.744432  ...                      1.000000
# 20                0.747357  ...                      1.000000
# 21                0.747927  ...                      1.000000
# 6                 0.732957  ...                      1.000000
# 7                 0.731252  ...                      1.000000
# 17                0.749160  ...                      1.000000
# 28                0.744145  ...                      1.000000
# 16                0.748762  ...                      1.000000
# 29                0.743234  ...                      1.000000
# 34                0.742759  ...                      1.000000
# 35                0.742704  ...                      1.000000
# 24                0.744243  ...                      0.999549
# 25                0.743130  ...                      0.999549
# 13                0.753613  ...                      0.999549
# 12                0.753105  ...                      0.999549
# 4                 0.729791  ...                      1.000000
# 5                 0.728916  ...                      1.000000
# 2                 0.732845  ...                      0.999549
# 3                 0.733399  ...                      0.999549
# 0                 0.728238  ...                      1.000000
# 23                0.741623  ...                      1.000000
# 22                0.743166  ...                      1.000000
# 1                 0.729017  ...                      1.000000
# 31                0.740102  ...                      1.000000
# 30                0.738793  ...                      1.000000
# 18                0.744336  ...                      1.000000
# 19                0.745221  ...                      1.000000
# 14                0.748618  ...                      0.999556
# 15                0.749401  ...                      0.999556
# 27                0.748625  ...                      0.999556
# 26                0.750034  ...                      0.999556
#
#     True Pos. Rate Mean  True Pos. Rate 95CI.LO  True Pos. Rate 95CI.HI  \
# 8              0.961819                0.950622                0.973015
# 9              0.963588                0.952969                0.974208
# 10             0.936337                0.916075                0.956598
# 11             0.935437                0.915152                0.955721
# 32             0.917930                0.890029                0.945831
# 33             0.915267                0.886900                0.943635
# 20             0.912050                0.892012                0.932088
# 21             0.914023                0.890905                0.937140
# 6              0.928067                0.911475                0.944659
# 7              0.920875                0.903655                0.938095
# 17             0.903982                0.887422                0.920543
# 28             0.914902                0.895240                0.934563
# 16             0.904954                0.886620                0.923287
# 29             0.913997                0.896281                0.931713
# 34             0.904890                0.887774                0.922007
# 35             0.904845                0.888298                0.921391
# 24             0.915448                0.899052                0.931844
# 25             0.913675                0.897070                0.930280
# 13             0.897097                0.880065                0.914129
# 12             0.898023                0.881104                0.914942
# 4              0.950337                0.933613                0.967061
# 5              0.947705                0.929855                0.965554
# 2              0.910360                0.887455                0.933266
# 3              0.906144                0.880113                0.932175
# 0              0.937524                0.920084                0.954965
# 23             0.868952                0.854536                0.883368
# 22             0.870749                0.856572                0.884925
# 1              0.937516                0.920063                0.954969
# 31             0.889508                0.880750                0.898265
# 30             0.886094                0.874731                0.897456
# 18             0.863049                0.841335                0.884763
# 19             0.865644                0.846189                0.885098
# 14             0.859316                0.840301                0.878330
# 15             0.860239                0.839782                0.880696
# 27             0.878359                0.861523                0.895195
# 26             0.881063                0.864586                0.897540
#
#     True Pos. Rate Training Mean  max_features n_estimators  \
# 8                            1.0             2          500
# 9                            1.0             2          500
# 10                           1.0             2          500
# 11                           1.0             2          500
# 32                           1.0          auto          500
# 33                           1.0          auto          500
# 20                           1.0            10          500
# 21                           1.0            10          500
# 6                            1.0             2          100
# 7                            1.0             2          100
# 17                           1.0            10          100
# 28                           1.0          auto          100
# 16                           1.0            10          100
# 29                           1.0          auto          100
# 34                           1.0          auto          500
# 35                           1.0          auto          500
# 24                           1.0          auto           50
# 25                           1.0          auto           50
# 13                           1.0            10           50
# 12                           1.0            10           50
# 4                            1.0             2          100
# 5                            1.0             2          100
# 2                            1.0             2           50
# 3                            1.0             2           50
# 0                            1.0             2           50
# 23                           1.0            10          500
# 22                           1.0            10          500
# 1                            1.0             2           50
# 31                           1.0          auto          100
# 30                           1.0          auto          100
# 18                           1.0            10          100
# 19                           1.0            10          100
# 14                           1.0            10           50
# 15                           1.0            10           50
# 27                           1.0          auto           50
# 26                           1.0          auto           50
#
#                    encoder          imputer            scaler
# 8          OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 9          OneHotEncoder()  SimpleImputer()  StandardScaler()
# 10  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 11  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 32         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 33         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 20         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 21         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 6   CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 7   CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 17         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 28         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 16         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 29         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 34  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 35  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 24         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 25         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 13         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 12         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 4          OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 5          OneHotEncoder()  SimpleImputer()  StandardScaler()
# 2   CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 3   CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 0          OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 23  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 22  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 1          OneHotEncoder()  SimpleImputer()  StandardScaler()
# 31  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 30  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 18  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 19  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 14  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 15  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 27  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 26  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
#
# [36 rows x 21 columns]

# %%
grid_search_parsed.formatted_results()
# Out:
# <style type="text/css">
# #T_4f1c9_row0_col0, #T_4f1c9_row1_col4, #T_4f1c9_row1_col12, #T_4f1c9_row18_col8, #T_4f1c9_row19_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 100.0%, transparent 100.0%);
# }
# #T_4f1c9_row0_col1, #T_4f1c9_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 96.6%, #B4B7B9 96.6%);
# }
# #T_4f1c9_row0_col2, #T_4f1c9_row1_col2, #T_4f1c9_row2_col2, #T_4f1c9_row10_col2, #T_4f1c9_row12_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 94.1%, transparent 94.1%);
# }
# #T_4f1c9_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 96.7%, transparent 96.7%);
# }
# #T_4f1c9_row0_col5, #T_4f1c9_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 96.4%, #B4B7B9 96.4%);
# }
# #T_4f1c9_row0_col6, #T_4f1c9_row1_col6, #T_4f1c9_row1_col14, #T_4f1c9_row6_col10, #T_4f1c9_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 100.0%, transparent 100.0%);
# }
# #T_4f1c9_row0_col8, #T_4f1c9_row1_col8, #T_4f1c9_row21_col10, #T_4f1c9_row30_col4, #T_4f1c9_row30_col6, #T_4f1c9_row32_col12, #T_4f1c9_row32_col14, #T_4f1c9_row34_col0, #T_4f1c9_row34_col2, #T_4f1c9_row35_col0 {
#   width: 10em;
#   height: 80%;
# }
# #T_4f1c9_row0_col9, #T_4f1c9_row1_col9, #T_4f1c9_row32_col5, #T_4f1c9_row32_col13, #T_4f1c9_row33_col1, #T_4f1c9_row33_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, #B4B7B9 100.0%, transparent 100.0%, transparent 100.0%, #B4B7B9 100.0%);
# }
# #T_4f1c9_row0_col10, #T_4f1c9_row1_col10 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 12.9%, transparent 12.9%);
# }
# #T_4f1c9_row0_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 98.1%, transparent 98.1%);
# }
# #T_4f1c9_row0_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 98.2%, #B4B7B9 98.2%);
# }
# #T_4f1c9_row0_col14 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 99.0%, transparent 99.0%);
# }
# #T_4f1c9_row0_col16, #T_4f1c9_row0_col17, #T_4f1c9_row0_col18, #T_4f1c9_row0_col19, #T_4f1c9_row1_col16, #T_4f1c9_row1_col17, #T_4f1c9_row1_col18, #T_4f1c9_row1_col19, #T_4f1c9_row2_col16, #T_4f1c9_row2_col17, #T_4f1c9_row2_col18, #T_4f1c9_row2_col19, #T_4f1c9_row3_col16, #T_4f1c9_row3_col17, #T_4f1c9_row3_col18, #T_4f1c9_row3_col19, #T_4f1c9_row4_col16, #T_4f1c9_row4_col17, #T_4f1c9_row4_col18, #T_4f1c9_row4_col19, #T_4f1c9_row5_col16, #T_4f1c9_row5_col17, #T_4f1c9_row5_col18, #T_4f1c9_row5_col19, #T_4f1c9_row6_col16, #T_4f1c9_row6_col17, #T_4f1c9_row6_col18, #T_4f1c9_row6_col19, #T_4f1c9_row7_col16, #T_4f1c9_row7_col17, #T_4f1c9_row7_col18, #T_4f1c9_row7_col19, #T_4f1c9_row8_col16, #T_4f1c9_row8_col17, #T_4f1c9_row8_col18, #T_4f1c9_row8_col19, #T_4f1c9_row9_col16, #T_4f1c9_row9_col17, #T_4f1c9_row9_col18, #T_4f1c9_row9_col19, #T_4f1c9_row10_col16, #T_4f1c9_row10_col17, #T_4f1c9_row10_col18, #T_4f1c9_row10_col19, #T_4f1c9_row11_col16, #T_4f1c9_row11_col17, #T_4f1c9_row11_col18, #T_4f1c9_row11_col19, #T_4f1c9_row12_col16, #T_4f1c9_row12_col17, #T_4f1c9_row12_col18, #T_4f1c9_row12_col19, #T_4f1c9_row13_col16, #T_4f1c9_row13_col17, #T_4f1c9_row13_col18, #T_4f1c9_row13_col19, #T_4f1c9_row14_col16, #T_4f1c9_row14_col17, #T_4f1c9_row14_col18, #T_4f1c9_row14_col19, #T_4f1c9_row15_col16, #T_4f1c9_row15_col17, #T_4f1c9_row15_col18, #T_4f1c9_row15_col19, #T_4f1c9_row16_col16, #T_4f1c9_row16_col17, #T_4f1c9_row16_col18, #T_4f1c9_row16_col19 {
#   background-color: #7AA9CF;
# }
# #T_4f1c9_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 96.4%, transparent 96.4%);
# }
# #T_4f1c9_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 93.1%, #B4B7B9 93.1%);
# }
# #T_4f1c9_row1_col13, #T_4f1c9_row8_col1, #T_4f1c9_row18_col9, #T_4f1c9_row20_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 100.0%, #B4B7B9 100.0%);
# }
# #T_4f1c9_row2_col0, #T_4f1c9_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 92.9%, transparent 92.9%);
# }
# #T_4f1c9_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 89.7%, #B4B7B9 89.7%);
# }
# #T_4f1c9_row2_col4, #T_4f1c9_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 80.0%, transparent 80.0%);
# }
# #T_4f1c9_row2_col5, #T_4f1c9_row3_col5, #T_4f1c9_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 89.3%, #B4B7B9 89.3%);
# }
# #T_4f1c9_row2_col6, #T_4f1c9_row3_col6, #T_4f1c9_row17_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 75.8%, transparent 75.8%);
# }
# #T_4f1c9_row2_col8, #T_4f1c9_row9_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 29.6%, transparent 29.6%);
# }
# #T_4f1c9_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 31.2%, #B4B7B9 31.2%);
# }
# #T_4f1c9_row2_col10, #T_4f1c9_row3_col10, #T_4f1c9_row9_col10 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 35.5%, transparent 35.5%);
# }
# #T_4f1c9_row2_col12, #T_4f1c9_row8_col4, #T_4f1c9_row13_col4, #T_4f1c9_row24_col4, #T_4f1c9_row27_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 73.3%, transparent 73.3%);
# }
# #T_4f1c9_row2_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 67.3%, #B4B7B9 67.3%);
# }
# #T_4f1c9_row2_col14 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 82.3%, transparent 82.3%);
# }
# #T_4f1c9_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 86.2%, #B4B7B9 86.2%);
# }
# #T_4f1c9_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 91.2%, transparent 91.2%);
# }
# #T_4f1c9_row3_col4, #T_4f1c9_row6_col4, #T_4f1c9_row16_col4, #T_4f1c9_row21_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 83.3%, transparent 83.3%);
# }
# #T_4f1c9_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 33.3%, transparent 33.3%);
# }
# #T_4f1c9_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 37.5%, #B4B7B9 37.5%);
# }
# #T_4f1c9_row3_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 72.4%, transparent 72.4%);
# }
# #T_4f1c9_row3_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 66.4%, #B4B7B9 66.4%);
# }
# #T_4f1c9_row3_col14 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 81.2%, transparent 81.2%);
# }
# #T_4f1c9_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 89.3%, transparent 89.3%);
# }
# #T_4f1c9_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 82.8%, #B4B7B9 82.8%);
# }
# #T_4f1c9_row4_col2, #T_4f1c9_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 88.2%, transparent 88.2%);
# }
# #T_4f1c9_row4_col6, #T_4f1c9_row21_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 72.7%, transparent 72.7%);
# }
# #T_4f1c9_row4_col8, #T_4f1c9_row17_col8, #T_4f1c9_row25_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 77.8%, transparent 77.8%);
# }
# #T_4f1c9_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 75.0%, #B4B7B9 75.0%);
# }
# #T_4f1c9_row4_col10, #T_4f1c9_row5_col10, #T_4f1c9_row11_col10, #T_4f1c9_row34_col10 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 74.2%, transparent 74.2%);
# }
# #T_4f1c9_row4_col12 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 56.2%, transparent 56.2%);
# }
# #T_4f1c9_row4_col13 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 44.2%, #B4B7B9 44.2%);
# }
# #T_4f1c9_row4_col14 {

# %%
grid_search_parsed.results.fillna(0).groupby('encoder').\
    agg({'ROC/AUC Mean': np.mean}).\
    sort_values(by='ROC/AUC Mean', ascending=False)
# Out:
#                         ROC/AUC Mean
# encoder
# OneHotEncoder()             0.762605
# CustomOrdinalEncoder()      0.754506

# %%
grid_search_parsed.results.fillna(0).groupby('scaler').\
    agg({'ROC/AUC Mean': np.mean}).\
    sort_values(by='ROC/AUC Mean', ascending=False)
# Out:
#                   ROC/AUC Mean
# scaler
# MinMaxScaler()        0.758696
# StandardScaler()      0.758415

# %%
grid_search_parsed.results.fillna(0).groupby('n_estimators').\
    agg({'ROC/AUC Mean': np.mean}).\
    sort_values(by='ROC/AUC Mean', ascending=False)
# Out:
#               ROC/AUC Mean
# n_estimators
# 500               0.765025
# 100               0.758518
# 50                0.752123

# %%
grid_search_parsed.results.fillna(0).groupby('max_features').\
    agg({'ROC/AUC Mean': np.mean}).\
    sort_values(by='ROC/AUC Mean', ascending=False)
# Out:
#               ROC/AUC Mean
# max_features
# 2                 0.761672
# auto              0.758313
# 10                0.755681

# %% [markdown]
# # Random Search

# %%
from scipy.stats import randint, uniform  # , expon

# %%
np.random.seed(42)
s = uniform(.2, .79).rvs(size=1000)
print(min(s))
print(max(s))
plt.hist(s)
# Out:
# 0.20365929817363626
# 0.9897769618960433
# (array([114., 112.,  95., 102.,  81., 111.,  98.,  88., 100.,  99.]),
#  array([0.2036593 , 0.28227106, 0.36088283, 0.4394946 , 0.51810636,
#         0.59671813, 0.6753299 , 0.75394166, 0.83255343, 0.9111652 ,
#         0.98977696]),
#  <BarContainer object of 10 artists>)

# %%
np.random.seed(42)
s = randint(2, 100).rvs(size=1000)
print(min(s))
print(max(s))
plt.hist(s)
# Out:
# 2
# 99
# (array([111., 105., 104.,  95.,  84., 112.,  98.,  89.,  83., 119.]),
#  array([ 2. , 11.7, 21.4, 31.1, 40.8, 50.5, 60.2, 69.9, 79.6, 89.3, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
del s

# %%
model_param_dict = [
    {
        'prep__numeric__impute__transformer': [SimpleImputer(strategy='mean')],
        'prep__numeric__scaling__transformer': [MinMaxScaler(), StandardScaler()],
        'prep__non_numeric__encoder__transformer': [
            OneHotEncoder(),
            hlp.sklearn_pipeline.CustomOrdinalEncoder()
        ],
        'model__n_estimators': randint(50, 5000),
        # If float, then max_features is a fraction and round(max_features * n_features) features are considered at each split.
        'model__max_features':  uniform(.01, .99),
    },
]

# %%
num_folds = 5
num_repeats = 2

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import RepeatedKFold
random_search = RandomizedSearchCV(
    estimator=full_pipeline,
    param_distributions=model_param_dict,
    n_iter=30,
    cv=RepeatedKFold(n_splits=num_folds, n_repeats=num_repeats),
    scoring='roc_auc',
    #return_train_score=True,
    n_jobs=-1,
    #verbose=2,
    random_state=42,
)
random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=RepeatedKFold(n_repeats=2, n_splits=5, random_state=None),
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(transformers=[('numeric',
#                                                                                Pipeline(steps=[('impute',
#                                                                                                 TransformerChooser()),
#                                                                                                ('scaling',
#                                                                                                 TransformerChooser())]),
#                                                                                ['duration',
#                                                                                 'credit_amount',
#                                                                                 'installment_commitment',
#                                                                                 'residence_since',
#                                                                                 'age',
#                                                                                 'existing_credits',
#                                                                                 'num_dependents'...
#                    param_distributions=[{'model__max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f994028f160>,
#                                          'model__n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f9940288670>,
#                                          'prep__non_numeric__encoder__transformer': [OneHotEncoder(),
#                                                                                      CustomOrdinalEncoder()],
#                                          'prep__numeric__impute__transformer': [SimpleImputer()],
#                                          'prep__numeric__scaling__transformer': [MinMaxScaler(),
#                                                                                  StandardScaler()]}],
#                    random_state=42, scoring='roc_auc')

# %% [markdown]
# ## Results

# %%
print(random_search.best_score_)
print(random_search.best_params_)
# Out:
# 0.761786753072665
# {'model__max_features': 0.02548004267378199, 'model__n_estimators': 2618, 'prep__non_numeric__encoder__transformer': CustomOrdinalEncoder(), 'prep__numeric__impute__transformer': SimpleImputer(), 'prep__numeric__scaling__transformer': MinMaxScaler()}

# %%
random_search_parsed = hlp.sklearn_eval.SearchCVParser(searcher=random_search,
                                                     higher_score_is_better = True,
                                                     new_param_column_names=new_param_column_names)
random_search_parsed.results
# Out:
#     roc_auc Mean  roc_auc 95CI.LO  roc_auc 95CI.HI  max_features  \
# 26      0.761787         0.739079         0.784495      0.025480
# 19      0.761054         0.739020         0.783088      0.193006
# 6       0.760692         0.738672         0.782712      0.191570
# 15      0.759128         0.736083         0.782172      0.248615
# 4       0.758984         0.735117         0.782851      0.030379
# 17      0.755798         0.735181         0.776415      0.266192
# 3       0.755147         0.733142         0.777153      0.340372
# 2       0.754998         0.733821         0.776176      0.164435
# 7       0.753948         0.731515         0.776382      0.016996
# 27      0.752456         0.730373         0.774538      0.206729
# 14      0.751495         0.730216         0.772773      0.391562
# 18      0.750225         0.727844         0.772606      0.430904
# 28      0.749953         0.728326         0.771580      0.206854
# 25      0.749251         0.728076         0.770427      0.283239
# 20      0.748699         0.727189         0.770209      0.455257
# 9       0.747442         0.724582         0.770302      0.372698
# 24      0.745509         0.723590         0.767428      0.590884
# 23      0.744602         0.722503         0.766701      0.332077
# 8       0.743689         0.721833         0.765544      0.615734
# 0       0.743205         0.721636         0.764774      0.380795
# 22      0.740631         0.719084         0.762178      0.574740
# 11      0.740497         0.719489         0.761504      0.596490
# 21      0.739593         0.717892         0.761295      0.601921
# 5       0.739565         0.718375         0.760755      0.939167
# 13      0.739478         0.718077         0.760879      0.949397
# 10      0.738651         0.716823         0.760478      0.622202
# 29      0.736934         0.714972         0.758896      0.773558
# 1       0.736864         0.715293         0.758435      0.781894
# 12      0.736733         0.715458         0.758008      0.683504
# 16      0.728120         0.708592         0.747648      0.834863
#
#     n_estimators                 encoder          imputer            scaler
# 26          2618  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 19          4848  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 6           4605  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 15          1528  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 4            819  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 17          3993  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 3           2969  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 2           4476         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 7           2954         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 27          1545         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 14          2662  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 18          2663  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 28           441         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 25          2112         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 20          4347  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 9            239  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()
# 24          4909  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 23           387         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 8           2097  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 0            910         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 22          1325         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 11          3252         OneHotEncoder()  SimpleImputer()    MinMaxScaler()
# 21          4961         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 5           2483  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 13          2413  CustomOrdinalEncoder()  SimpleImputer()  StandardScaler()
# 10          1949         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 29          3611         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 1           3142         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 12          2938         OneHotEncoder()  SimpleImputer()  StandardScaler()
# 16            84  CustomOrdinalEncoder()  SimpleImputer()    MinMaxScaler()

# %%
# import plotly.express as px
#
# fig = px.line(x=["a","b","c"],
#               y=[1,3,2],
#               title="sample figure")
# fig.show()

# %%
random_search_parsed.formatted_results()
# Out:
# <style type="text/css">
# #T_f8b1f_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 100.0%, transparent 100.0%);
# }
# #T_f8b1f_row0_col1, #T_f8b1f_row1_col1, #T_f8b1f_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 100.0%, #B4B7B9 100.0%);
# }
# #T_f8b1f_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 100.0%, transparent 100.0%);
# }
# #T_f8b1f_row0_col3, #T_f8b1f_row0_col4, #T_f8b1f_row0_col5, #T_f8b1f_row0_col6, #T_f8b1f_row1_col3, #T_f8b1f_row1_col4, #T_f8b1f_row1_col5, #T_f8b1f_row1_col6, #T_f8b1f_row2_col3, #T_f8b1f_row2_col4, #T_f8b1f_row2_col5, #T_f8b1f_row2_col6, #T_f8b1f_row3_col3, #T_f8b1f_row3_col4, #T_f8b1f_row3_col5, #T_f8b1f_row3_col6, #T_f8b1f_row4_col3, #T_f8b1f_row4_col4, #T_f8b1f_row4_col5, #T_f8b1f_row4_col6, #T_f8b1f_row5_col3, #T_f8b1f_row5_col4, #T_f8b1f_row5_col5, #T_f8b1f_row5_col6, #T_f8b1f_row6_col3, #T_f8b1f_row6_col4, #T_f8b1f_row6_col5, #T_f8b1f_row6_col6, #T_f8b1f_row7_col3, #T_f8b1f_row7_col4, #T_f8b1f_row7_col5, #T_f8b1f_row7_col6, #T_f8b1f_row8_col3, #T_f8b1f_row8_col4, #T_f8b1f_row8_col5, #T_f8b1f_row8_col6, #T_f8b1f_row9_col3, #T_f8b1f_row9_col4, #T_f8b1f_row9_col5, #T_f8b1f_row9_col6 {
#   background-color: #7AA9CF;
# }
# #T_f8b1f_row1_col0, #T_f8b1f_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 97.1%, transparent 97.1%);
# }
# #T_f8b1f_row1_col2, #T_f8b1f_row2_col2, #T_f8b1f_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 97.2%, transparent 97.2%);
# }
# #T_f8b1f_row3_col0, #T_f8b1f_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 91.2%, transparent 91.2%);
# }
# #T_f8b1f_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 90.0%, #B4B7B9 90.0%);
# }
# #T_f8b1f_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 94.4%, transparent 94.4%);
# }
# #T_f8b1f_row4_col1, #T_f8b1f_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 86.7%, #B4B7B9 86.7%);
# }
# #T_f8b1f_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 82.4%, transparent 82.4%);
# }
# #T_f8b1f_row5_col2, #T_f8b1f_row7_col2, #T_f8b1f_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 77.8%, transparent 77.8%);
# }
# #T_f8b1f_row6_col0, #T_f8b1f_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 79.4%, transparent 79.4%);
# }
# #T_f8b1f_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 80.0%, #B4B7B9 80.0%);
# }
# #T_f8b1f_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 80.6%, transparent 80.6%);
# }
# #T_f8b1f_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 83.3%, #B4B7B9 83.3%);
# }
# #T_f8b1f_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 76.5%, transparent 76.5%);
# }
# #T_f8b1f_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 76.7%, #B4B7B9 76.7%);
# }
# #T_f8b1f_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 70.6%, transparent 70.6%);
# }
# #T_f8b1f_row9_col1, #T_f8b1f_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 70.0%, #B4B7B9 70.0%);
# }
# #T_f8b1f_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 75.0%, transparent 75.0%);
# }
# #T_f8b1f_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 67.6%, transparent 67.6%);
# }
# #T_f8b1f_row10_col2, #T_f8b1f_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 69.4%, transparent 69.4%);
# }
# #T_f8b1f_row11_col0, #T_f8b1f_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 64.7%, transparent 64.7%);
# }
# #T_f8b1f_row11_col1, #T_f8b1f_row12_col1, #T_f8b1f_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 63.3%, #B4B7B9 63.3%);
# }
# #T_f8b1f_row12_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 66.7%, transparent 66.7%);
# }
# #T_f8b1f_row13_col0, #T_f8b1f_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 61.8%, transparent 61.8%);
# }
# #T_f8b1f_row13_col2, #T_f8b1f_row14_col2, #T_f8b1f_row15_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 61.1%, transparent 61.1%);
# }
# #T_f8b1f_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 60.0%, #B4B7B9 60.0%);
# }
# #T_f8b1f_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 55.9%, transparent 55.9%);
# }
# #T_f8b1f_row15_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 53.3%, #B4B7B9 53.3%);
# }
# #T_f8b1f_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 52.9%, transparent 52.9%);
# }
# #T_f8b1f_row16_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 50.0%, #B4B7B9 50.0%);
# }
# #T_f8b1f_row16_col2, #T_f8b1f_row17_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 52.8%, transparent 52.8%);
# }
# #T_f8b1f_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 50.0%, transparent 50.0%);
# }
# #T_f8b1f_row17_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 46.7%, #B4B7B9 46.7%);
# }
# #T_f8b1f_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 47.1%, transparent 47.1%);
# }
# #T_f8b1f_row18_col1, #T_f8b1f_row19_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 43.3%, #B4B7B9 43.3%);
# }
# #T_f8b1f_row18_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 50.0%, transparent 50.0%);
# }
# #T_f8b1f_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 44.1%, transparent 44.1%);
# }
# #T_f8b1f_row19_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 47.2%, transparent 47.2%);
# }
# #T_f8b1f_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 38.2%, transparent 38.2%);
# }
# #T_f8b1f_row20_col1, #T_f8b1f_row21_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 33.3%, #B4B7B9 33.3%);
# }
# #T_f8b1f_row20_col2, #T_f8b1f_row21_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 38.9%, transparent 38.9%);
# }
# #T_f8b1f_row21_col0, #T_f8b1f_row22_col0, #T_f8b1f_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 35.3%, transparent 35.3%);
# }
# #T_f8b1f_row22_col1, #T_f8b1f_row23_col1, #T_f8b1f_row24_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 30.0%, #B4B7B9 30.0%);
# }
# #T_f8b1f_row22_col2, #T_f8b1f_row23_col2, #T_f8b1f_row24_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 36.1%, transparent 36.1%);
# }
# #T_f8b1f_row24_col0, #T_f8b1f_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 32.4%, transparent 32.4%);
# }
# #T_f8b1f_row25_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 26.7%, #B4B7B9 26.7%);
# }
# #T_f8b1f_row25_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 33.3%, transparent 33.3%);
# }
# #T_f8b1f_row26_col0, #T_f8b1f_row27_col0, #T_f8b1f_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 26.5%, transparent 26.5%);
# }
# #T_f8b1f_row26_col1, #T_f8b1f_row27_col1, #T_f8b1f_row28_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 20.0%, #B4B7B9 20.0%);
# }
# #T_f8b1f_row26_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 30.6

# %%
random_search_parsed.results.fillna(0).groupby('encoder').\
    agg({'roc_auc Mean': np.mean}).\
    sort_values(by='roc_auc Mean', ascending=False)
# Out:
#                         roc_auc Mean
# encoder
# CustomOrdinalEncoder()      0.750426
# OneHotEncoder()             0.744166

# %%
import matplotlib.pyplot as plt
plt.xlim(0, 1)
sns.set(rc={'figure.figsize': hlp.plot.STANDARD_WIDTH_HEIGHT})
sns.scatterplot(data=random_search_parsed.results, x="max_features", y="roc_auc Mean")
plt.show()

# %%
sns.set(rc={'figure.figsize': hlp.plot.STANDARD_WIDTH_HEIGHT})
sns.scatterplot(data=random_search_parsed.results,
                x="n_estimators",
                y="roc_auc Mean",
                size='max_features')
plt.show()

# %%
sns.set(rc={'figure.figsize': hlp.plot.STANDARD_WIDTH_HEIGHT})
sns.lineplot(data=random_search_parsed.results,
                x="n_estimators",
                y="roc_auc Mean",
                hue=pd.cut(random_search_parsed.results['max_features'], bins=np.linspace(0,1,11)))
plt.show()

# %%
sns.regplot(x='n_estimators',
            y='roc_auc Mean',
            data=random_search_parsed.results,
            scatter_kws={'s': random_search_parsed.results['max_features']*100},
            lowess=True)
#plt.title("Average ROC_AUC over all iterations")
#plt.ylabel("Average ROC_AUC")
#plt.xlabel("")
plt.tight_layout()

# %%
sns.lmplot(x='n_estimators',
            y='roc_auc Mean',
            data=random_search_parsed.results)
#plt.title("Average ROC_AUC over all iterations")
#plt.ylabel("Average ROC_AUC")
#plt.xlabel("")
plt.tight_layout()

# %%
sns.lmplot(x='n_estimators',
            y='roc_auc Mean',
            hue='encoder',
           data=random_search_parsed.results)
            #lowess=True)
#plt.title("Average ROC_AUC over all iterations")
#plt.ylabel("Average ROC_AUC")
#plt.xlabel("")
plt.tight_layout()

# %%
sns.set(rc={'figure.figsize': hlp.plot.STANDARD_WIDTH_HEIGHT})
sns.lineplot(data=random_search_parsed.results,
                x="n_estimators",
                y="roc_auc Mean",
             hue='encoder')
plt.show()

# %%
sns.set(rc={'figure.figsize': hlp.plot.STANDARD_WIDTH_HEIGHT})
sns.relplot(data=random_search_parsed.results,
            kind='line',
            x="n_estimators",
            y="roc_auc Mean",
            hue=pd.cut(random_search_parsed.results['max_features'], bins=np.linspace(0,1,11)),
            col='encoder')
plt.show()

# %% [markdown]
# # skopt.BayesSearchCV
#
# [https://scikit-optimize.github.io/stable/auto_examples/sklearn-gridsearchcv-replacement.html](https://scikit-optimize.github.io/stable/auto_examples/sklearn-gridsearchcv-replacement.html)

# %%
# pip install scikit-optimize
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

# %%
search_space = {
    'prep__numeric__impute__transformer': Categorical([SimpleImputer(strategy='mean')]),
    'prep__numeric__scaling__transformer': Categorical([MinMaxScaler(), StandardScaler()]),
    'prep__non_numeric__encoder__transformer': Categorical([
        OneHotEncoder(),
        hlp.sklearn_pipeline.CustomOrdinalEncoder()
    ]),
    'model__n_estimators': Integer(50, 5000),
    # If float, then max_features is a fraction and round(max_features * n_features) features are considered at each split.
    'model__max_features':  Real(.01, .99),
}

bayes_search = BayesSearchCV(
    estimator=full_pipeline,
    search_spaces=search_space,
    n_iter=30,
    cv=RepeatedKFold(n_splits=num_folds, n_repeats=num_repeats),
    scoring='roc_auc',
    #return_train_score=True,
    n_jobs=-1,
    verbose=1,
    random_state=42,
)
bayes_search.fit(X_train, y_train)

del search_space
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Fitting 10 folds for each of 1 candidates, totalling 10 fits

# %% [markdown]
# ## Results

# %%
print(bayes_search.cv.n_repeats)
print(bayes_search.cv.cvargs['n_splits'])
# Out:
# 2
# 5

# %%
print(bayes_search.best_score_)
print(bayes_search.best_params_)
# Out:
# 0.7753529963902321
# OrderedDict([('model__max_features', 0.01), ('model__n_estimators', 1824), ('prep__non_numeric__encoder__transformer', CustomOrdinalEncoder()), ('prep__numeric__impute__transformer', SimpleImputer()), ('prep__numeric__scaling__transformer', MinMaxScaler())])

# %%
new_param_column_names
# Out:
# {'model | max_features': 'max_features',
#  'model | n_estimators': 'n_estimators',
#  'prep | non_numeric | encoder | transformer': 'encoder',
#  'prep | numeric | impute | transformer': 'imputer',
#  'prep | numeric | scaling | transformer': 'scaler'}

# %%
bayes_search_parsed = hlp.sklearn_eval.SearchCVParser(searcher=bayes_search,
                                                      higher_score_is_better = True,
                                                      new_param_column_names=new_param_column_names)

# %%
bayes_search_parsed.formatted_results()
# Out:
# <style type="text/css">
# #T_f554e_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 100.0%, transparent 100.0%);
# }
# #T_f554e_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 100.0%, #B4B7B9 100.0%);
# }
# #T_f554e_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 100.0%, transparent 100.0%);
# }
# #T_f554e_row0_col3, #T_f554e_row0_col4, #T_f554e_row0_col5, #T_f554e_row0_col6, #T_f554e_row1_col3, #T_f554e_row1_col4, #T_f554e_row1_col5, #T_f554e_row1_col6, #T_f554e_row2_col3, #T_f554e_row2_col4, #T_f554e_row2_col5, #T_f554e_row2_col6, #T_f554e_row3_col3, #T_f554e_row3_col4, #T_f554e_row3_col5, #T_f554e_row3_col6, #T_f554e_row4_col3, #T_f554e_row4_col4, #T_f554e_row4_col5, #T_f554e_row4_col6 {
#   background-color: #7AA9CF;
# }
# #T_f554e_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 86.4%, transparent 86.4%);
# }
# #T_f554e_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 86.4%, #B4B7B9 86.4%);
# }
# #T_f554e_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 86.3%, transparent 86.3%);
# }
# #T_f554e_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 79.5%, transparent 79.5%);
# }
# #T_f554e_row2_col1, #T_f554e_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 77.3%, #B4B7B9 77.3%);
# }
# #T_f554e_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 80.4%, transparent 80.4%);
# }
# #T_f554e_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 77.3%, transparent 77.3%);
# }
# #T_f554e_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 88.6%, #B4B7B9 88.6%);
# }
# #T_f554e_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 68.6%, transparent 68.6%);
# }
# #T_f554e_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 72.7%, transparent 72.7%);
# }
# #T_f554e_row4_col1, #T_f554e_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 81.8%, #B4B7B9 81.8%);
# }
# #T_f554e_row4_col2, #T_f554e_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 66.7%, transparent 66.7%);
# }
# #T_f554e_row5_col0, #T_f554e_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 70.5%, transparent 70.5%);
# }
# #T_f554e_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 72.7%, #B4B7B9 72.7%);
# }
# #T_f554e_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 72.5%, transparent 72.5%);
# }
# #T_f554e_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 68.2%, #B4B7B9 68.2%);
# }
# #T_f554e_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 74.5%, transparent 74.5%);
# }
# #T_f554e_row7_col0, #T_f554e_row8_col0, #T_f554e_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 65.9%, transparent 65.9%);
# }
# #T_f554e_row7_col2, #T_f554e_row15_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 58.8%, transparent 58.8%);
# }
# #T_f554e_row8_col1, #T_f554e_row11_col1, #T_f554e_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 63.6%, #B4B7B9 63.6%);
# }
# #T_f554e_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 70.6%, transparent 70.6%);
# }
# #T_f554e_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 52.9%, transparent 52.9%);
# }
# #T_f554e_row10_col0, #T_f554e_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 63.6%, transparent 63.6%);
# }
# #T_f554e_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 75.0%, #B4B7B9 75.0%);
# }
# #T_f554e_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 56.9%, transparent 56.9%);
# }
# #T_f554e_row12_col0, #T_f554e_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 45.5%, transparent 45.5%);
# }
# #T_f554e_row12_col2, #T_f554e_row18_col2, #T_f554e_row21_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 37.3%, transparent 37.3%);
# }
# #T_f554e_row13_col1, #T_f554e_row24_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 56.8%, #B4B7B9 56.8%);
# }
# #T_f554e_row13_col2, #T_f554e_row22_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 43.1%, transparent 43.1%);
# }
# #T_f554e_row14_col0, #T_f554e_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 43.2%, transparent 43.2%);
# }
# #T_f554e_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 65.9%, #B4B7B9 65.9%);
# }
# #T_f554e_row14_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 29.4%, transparent 29.4%);
# }
# #T_f554e_row15_col1, #T_f554e_row21_col1, #T_f554e_row23_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 31.8%, #B4B7B9 31.8%);
# }
# #T_f554e_row16_col0, #T_f554e_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 40.9%, transparent 40.9%);
# }
# #T_f554e_row16_col1, #T_f554e_row17_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 54.5%, #B4B7B9 54.5%);
# }
# #T_f554e_row16_col2, #T_f554e_row17_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 35.3%, transparent 35.3%);
# }
# #T_f554e_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 38.6%, transparent 38.6%);
# }
# #T_f554e_row18_col1, #T_f554e_row20_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 50.0%, #B4B7B9 50.0%);
# }
# #T_f554e_row19_col0, #T_f554e_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 36.4%, transparent 36.4%);
# }
# #T_f554e_row19_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 61.4%, #B4B7B9 61.4%);
# }
# #T_f554e_row19_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 23.5%, transparent 23.5%);
# }
# #T_f554e_row20_col2, #T_f554e_row23_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 31.4%, transparent 31.4%);
# }
# #T_f554e_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 31.8%, transparent 31.8%);
# }
# #T_f554e_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 29.5%, transparent 29.5%);
# }
# #T_f554e_row22_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 22.7%, #B4B7B9 22.7%);
# }
# #T_f554e_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 27.3%, transparent 27.3%);
# }
# #T_f554e_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 22.7%, transparent 22.7%);
# }
# #T_f554e_row24_col2, #T_f554e_row29_col0 {
#   width: 10em;
#   height: 80%;
# }
# #T_f554e_row25_col0, #T_f554e_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 20.5%, transparent 20.5%);
# }
# #T_f554e_row25_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 13.6%, #B4B7B9 13.6%);
# }
# #T_f554e_row25_col2, #T_f554e_row26_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 33.3%, transparent 33.3%);
# }
# #T_f554e_row26_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,transparent 15.9%, #B4B7B9 15.9%);
# }
# #T_f554e_row27_col0, #T_f554e_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 18.2%, transparent 18.2%);
# }
# #T_f554e_row27_col1 {
#   width: 10em;
#   height: 80%;

# %%
sns.regplot(x=np.arange(0, len(bayes_search_parsed.results)), y=bayes_search_parsed.results.sort_index()['roc_auc Mean'], lowess=True)
plt.title("Average ROC_AUC over all iterations")
plt.ylabel("Average ROC_AUC")
plt.xlabel("Iteration")
plt.tight_layout()

# %%
bayes_search_parsed.results.sort_index()['roc_auc Mean'].plot()
plt.title("Average ROC_AUC over all iterations")
plt.ylabel("Average ROC_AUC")
plt.xlabel("Iteration")
plt.tight_layout()

# %% [markdown]
# # Final Model

# %%
best_model = bayes_search.best_estimator_

# %%
best_model.classes_
# Out:
# array([0, 1])

# %% [markdown]
# ## Training Set Evaluation

# %% [markdown]
# Understand the nature/degree of model overfitting by comparing to `Test Set Evaluation`

# %%
predicted_scores = best_model.predict_proba(X_train)[:, 1]

# %%
sns.histplot(predicted_scores)
plt.tight_layout()

# %%
evaluator = hlp.sklearn_eval.TwoClassEvaluator(
    actual_values=y_train,
    predicted_scores=predicted_scores,
    labels=('Bad', 'Good'),
    score_threshold=0.5
)

# %%
evaluator.all_metrics_df(return_style=True, round_by=3)
# Out:
# <style type="text/css">
# #T_7e827_row0_col0, #T_7e827_row1_col0, #T_7e827_row2_col0, #T_7e827_row5_col0, #T_7e827_row6_col0, #T_7e827_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 100.0%, transparent 100.0%);
# }
# #T_7e827_row3_col0, #T_7e827_row4_col0, #T_7e827_row9_col0 {
#   width: 10em;
#   height: 80%;
#   width: 10em;
#   height: 80%;
# }
# #T_7e827_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 100.0%, transparent 100.0%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 100.0%, transparent 100.0%);
# }
# #T_7e827_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 69.9%, transparent 69.9%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 69.9%, transparent 69.9%);
# }
# </style>
# <table id="T_7e827_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Scores</th>
#       <th class="col_heading level0 col1" >Details</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e827_level0_row0" class="row_heading level0 row0" >AUC</th>
#       <td id="T_7e827_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_7e827_row0_col1" class="data row0 col1" >Area under the ROC curve (true pos. rate vs false pos. rate); ranges from 0.5 (purely random classifier) to 1.0 (perfect classifier)</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row1" class="row_heading level0 row1" >True Positive Rate</th>
#       <td id="T_7e827_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_7e827_row1_col1" class="data row1 col1" >100.0% of positive instances were correctly identified.; i.e. 559 "Good" labels were correctly identified out of 559 instances; a.k.a Sensitivity/Recall</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row2" class="row_heading level0 row2" >True Negative Rate</th>
#       <td id="T_7e827_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_7e827_row2_col1" class="data row2 col1" >100.0% of negative instances were correctly identified.; i.e. 241 "Bad" labels were correctly identified out of 241 instances</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row3" class="row_heading level0 row3" >False Positive Rate</th>
#       <td id="T_7e827_row3_col0" class="data row3 col0" >0.000</td>
#       <td id="T_7e827_row3_col1" class="data row3 col1" >0.0% of negative instances were incorrectly identified as positive; i.e. 0 "Bad" labels were incorrectly identified as "Good", out of 241 instances</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row4" class="row_heading level0 row4" >False Negative Rate</th>
#       <td id="T_7e827_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_7e827_row4_col1" class="data row4 col1" >0.0% of positive instances were incorrectly identified as negative; i.e. 0 "Good" labels were incorrectly identified as "Bad", out of 559 instances</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row5" class="row_heading level0 row5" >Positive Predictive Value</th>
#       <td id="T_7e827_row5_col0" class="data row5 col0" >1.000</td>
#       <td id="T_7e827_row5_col1" class="data row5 col1" >When the model claims an instance is positive, it is correct 100.0% of the time; i.e. out of the 559 times the model predicted "Good", it was correct 559 times; a.k.a precision</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row6" class="row_heading level0 row6" >Negative Predictive Value</th>
#       <td id="T_7e827_row6_col0" class="data row6 col0" >1.000</td>
#       <td id="T_7e827_row6_col1" class="data row6 col1" >When the model claims an instance is negative, it is correct 100.0% of the time; i.e. out of the 241 times the model predicted "Bad", it was correct 241 times</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row7" class="row_heading level0 row7" >F1 Score</th>
#       <td id="T_7e827_row7_col0" class="data row7 col0" >1.000</td>
#       <td id="T_7e827_row7_col1" class="data row7 col1" >The F1 score can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0.</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row8" class="row_heading level0 row8" >Accuracy</th>
#       <td id="T_7e827_row8_col0" class="data row8 col0" >1.000</td>
#       <td id="T_7e827_row8_col1" class="data row8 col1" >100.0% of instances were correctly identified</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row9" class="row_heading level0 row9" >Error Rate</th>
#       <td id="T_7e827_row9_col0" class="data row9 col0" >0.000</td>
#       <td id="T_7e827_row9_col1" class="data row9 col1" >0.0% of instances were incorrectly identified</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row10" class="row_heading level0 row10" >% Positive</th>
#       <td id="T_7e827_row10_col0" class="data row10 col0" >0.699</td>
#       <td id="T_7e827_row10_col1" class="data row10 col1" >69.9% of the data are positive; i.e. out of 800 total observations; 559 are labeled as "Good"</td>
#     </tr>
#     <tr>
#       <th id="T_7e827_level0_row11" class="row_heading level0 row11" >Total Observations</th>
#       <td id="T_7e827_row11_col0" class="data row11 col0" >800</td>
#       <td id="T_7e827_row11_col1" class="data row11 col1" >There are 800 total observations; i.e. sample size</td>
#     </tr>
#   </tbody>
# </table>

# %%
del predicted_scores

# %% [markdown]
# ## Test Set Evaluation

# %%
predicted_scores = best_model.predict_proba(X_test)[:, 1]

# %%
predicted_scores
# Out:
# array([0.56798246, 0.64309211, 0.37171053, 0.66666667, 0.85800439,
#        0.66557018, 0.90405702, 0.58333333, 0.87445175, 0.8004386 ,
#        0.80811404, 0.57510965, 0.7872807 , 0.42598684, 0.28563596,
#        0.66337719, 0.80372807, 0.83662281, 0.49177632, 0.70230263,
#        0.72039474, 0.73903509, 0.87445175, 0.97313596, 0.94078947,
#        0.59210526, 0.4627193 , 0.58881579, 0.71326754, 0.80208333,
#        0.67653509, 0.78618421, 0.63212719, 0.73464912, 0.77083333,
#        0.72258772, 0.5       , 0.77083333, 0.89199561, 0.51315789,
#        0.70942982, 0.79166667, 0.66611842, 0.80098684, 0.8497807 ,
#        0.72861842, 0.56578947, 0.63322368, 0.70230263, 0.75712719,
#        0.44133772, 0.86567982, 0.70010965, 0.50274123, 0.75      ,
#        0.74506579, 0.9002193 , 0.47258772, 0.47697368, 0.81304825,
#        0.76973684, 0.59758772, 0.62774123, 0.91666667, 0.6129386 ,
#        0.69078947, 0.86019737, 0.60964912, 0.60197368, 0.78782895,
#        0.57072368, 0.85416667, 0.78015351, 0.66995614, 0.61074561,
#        0.6683114 , 0.74067982, 0.68914474, 0.67763158, 0.64254386,
#        0.7560307 , 0.77192982, 0.92598684, 0.67434211, 0.79660088,
#        0.56798246, 0.45175439, 0.36951754, 0.76644737, 0.8558114 ,
#        0.52083333, 0.89528509, 0.22752193, 0.55153509, 0.89583333,
#        0.80701754, 0.85471491, 0.70888158, 0.34484649, 0.65734649,
#        0.91776316, 0.72094298, 0.82182018, 0.86348684, 0.81907895,
#        0.76699561, 0.65460526, 0.57894737, 0.7247807 , 0.54276316,
#        0.45942982, 0.82620614, 0.55592105, 0.84320175, 0.71600877,
#        0.73245614, 0.6058114 , 0.74122807, 0.8810307 , 0.60635965,
#        0.64144737, 0.60197368, 0.71765351, 0.7752193 , 0.54002193,
#        0.75657895, 0.58826754, 0.8185307 , 0.85910088, 0.56140351,
#        0.78892544, 0.81304825, 0.71162281, 0.7127193 , 0.76973684,
#        0.77850877, 0.58607456, 0.85635965, 0.75657895, 0.64747807,
#        0.6995614 , 0.68640351, 0.5191886 , 0.86403509, 0.66557018,
#        0.57894737, 0.65076754, 0.76151316, 0.53070175, 0.55592105,
#        0.85471491, 0.66721491, 0.80592105, 0.65899123, 0.9254386 ,
#        0.59375   , 0.63377193, 0.74232456, 0.76041667, 0.64089912,
#        0.60855263, 0.82510965, 0.54166667, 0.43640351, 0.54769737,
#        0.67708333, 0.88157895, 0.80208333, 0.90570175, 0.59046053,
#        0.87390351, 0.75274123, 0.59100877, 0.69407895, 0.90899123,
#        0.71875   , 0.59703947, 0.85690789, 0.61458333, 0.5120614 ,
#        0.89254386, 0.79879386, 0.83388158, 0.68201754, 0.79057018,
#        0.83004386, 0.59155702, 0.87335526, 0.83826754, 0.87719298,
#        0.82127193, 0.52850877, 0.40789474, 0.60690789, 0.71326754,
#        0.80372807, 0.3870614 , 0.49835526, 0.47861842, 0.67598684])

# %%
sns.histplot(predicted_scores)
plt.tight_layout()

# %%
y_test_cat = pd.Series(y_test).replace({1: 'Defaulted', 0: 'Not Defaulted'})
y_test_cat.head()
# Out:
# 0    Not Defaulted
# 1        Defaulted
# 2        Defaulted
# 3        Defaulted
# 4        Defaulted
# dtype: object

# %%
axes = sns.displot(
    pd.DataFrame({
        'prediction': predicted_scores,
        'actual': y_test_cat
    }),
    x='prediction',
    col='actual'
)
for axis in axes.axes.flat:
    axis.axvline(x=0.5, ymin=0, ymax=100, color='red')
plt.tight_layout()

# %%
del y_test_cat
del axes

# %%
evaluator = hlp.sklearn_eval.TwoClassEvaluator(
    actual_values=y_test,
    predicted_scores=predicted_scores,
    labels=('Bad', 'Good'),
    score_threshold=0.5
)

# %%
evaluator.plot_confusion_matrix()

# %%
evaluator.all_metrics_df(return_style=True, round_by=3)
# Out:
# <style type="text/css">
# #T_74fa7_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 79.6%, transparent 79.6%);
# }
# #T_74fa7_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 95.0%, transparent 95.0%);
# }
# #T_74fa7_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 20.3%, transparent 20.3%);
# }
# #T_74fa7_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 79.7%, transparent 79.7%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF420E 79.7%, transparent 79.7%);
# }
# #T_74fa7_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 5.0%, transparent 5.0%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF420E 5.0%, transparent 5.0%);
# }
# #T_74fa7_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 74.0%, transparent 74.0%);
# }
# #T_74fa7_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 63.2%, transparent 63.2%);
# }
# #T_74fa7_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 83.2%, transparent 83.2%);
# }
# #T_74fa7_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 73.0%, transparent 73.0%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 73.0%, transparent 73.0%);
# }
# #T_74fa7_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 27.0%, transparent 27.0%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 27.0%, transparent 27.0%);
# }
# #T_74fa7_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 70.5%, transparent 70.5%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 70.5%, transparent 70.5%);
# }
# </style>
# <table id="T_74fa7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Scores</th>
#       <th class="col_heading level0 col1" >Details</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74fa7_level0_row0" class="row_heading level0 row0" >AUC</th>
#       <td id="T_74fa7_row0_col0" class="data row0 col0" >0.796</td>
#       <td id="T_74fa7_row0_col1" class="data row0 col1" >Area under the ROC curve (true pos. rate vs false pos. rate); ranges from 0.5 (purely random classifier) to 1.0 (perfect classifier)</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row1" class="row_heading level0 row1" >True Positive Rate</th>
#       <td id="T_74fa7_row1_col0" class="data row1 col0" >0.950</td>
#       <td id="T_74fa7_row1_col1" class="data row1 col1" >95.0% of positive instances were correctly identified.; i.e. 134 "Good" labels were correctly identified out of 141 instances; a.k.a Sensitivity/Recall</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row2" class="row_heading level0 row2" >True Negative Rate</th>
#       <td id="T_74fa7_row2_col0" class="data row2 col0" >0.203</td>
#       <td id="T_74fa7_row2_col1" class="data row2 col1" >20.3% of negative instances were correctly identified.; i.e. 12 "Bad" labels were correctly identified out of 59 instances</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row3" class="row_heading level0 row3" >False Positive Rate</th>
#       <td id="T_74fa7_row3_col0" class="data row3 col0" >0.797</td>
#       <td id="T_74fa7_row3_col1" class="data row3 col1" >79.7% of negative instances were incorrectly identified as positive; i.e. 47 "Bad" labels were incorrectly identified as "Good", out of 59 instances</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row4" class="row_heading level0 row4" >False Negative Rate</th>
#       <td id="T_74fa7_row4_col0" class="data row4 col0" >0.050</td>
#       <td id="T_74fa7_row4_col1" class="data row4 col1" >5.0% of positive instances were incorrectly identified as negative; i.e. 7 "Good" labels were incorrectly identified as "Bad", out of 141 instances</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row5" class="row_heading level0 row5" >Positive Predictive Value</th>
#       <td id="T_74fa7_row5_col0" class="data row5 col0" >0.740</td>
#       <td id="T_74fa7_row5_col1" class="data row5 col1" >When the model claims an instance is positive, it is correct 74.0% of the time; i.e. out of the 181 times the model predicted "Good", it was correct 134 times; a.k.a precision</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row6" class="row_heading level0 row6" >Negative Predictive Value</th>
#       <td id="T_74fa7_row6_col0" class="data row6 col0" >0.632</td>
#       <td id="T_74fa7_row6_col1" class="data row6 col1" >When the model claims an instance is negative, it is correct 63.2% of the time; i.e. out of the 19 times the model predicted "Bad", it was correct 12 times</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row7" class="row_heading level0 row7" >F1 Score</th>
#       <td id="T_74fa7_row7_col0" class="data row7 col0" >0.832</td>
#       <td id="T_74fa7_row7_col1" class="data row7 col1" >The F1 score can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0.</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row8" class="row_heading level0 row8" >Accuracy</th>
#       <td id="T_74fa7_row8_col0" class="data row8 col0" >0.730</td>
#       <td id="T_74fa7_row8_col1" class="data row8 col1" >73.0% of instances were correctly identified</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row9" class="row_heading level0 row9" >Error Rate</th>
#       <td id="T_74fa7_row9_col0" class="data row9 col0" >0.270</td>
#       <td id="T_74fa7_row9_col1" class="data row9 col1" >27.0% of instances were incorrectly identified</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row10" class="row_heading level0 row10" >% Positive</th>
#       <td id="T_74fa7_row10_col0" class="data row10 col0" >0.705</td>
#       <td id="T_74fa7_row10_col1" class="data row10 col1" >70.5% of the data are positive; i.e. out of 200 total observations; 141 are labeled as "Good"</td>
#     </tr>
#     <tr>
#       <th id="T_74fa7_level0_row11" class="row_heading level0 row11" >Total Observations</th>
#       <td id="T_74fa7_row11_col0" class="data row11 col0" >200</td>
#       <td id="T_74fa7_row11_col1" class="data row11 col1" >There are 200 total observations; i.e. sample size</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Compare results against scores if we predicted all `Good`

# %%
dummy_predicted_scores = np.array([0.99] * len(predicted_scores))

# %%
dummy_eval = hlp.sklearn_eval.TwoClassEvaluator(
    actual_values=y_test,
    predicted_scores=dummy_predicted_scores,
    labels=('Bad', 'Good'),
    score_threshold=0.5
)
dummy_eval.all_metrics_df(return_style=True, round_by=3)
# Out:
# <style type="text/css">
# #T_26eac_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 50.0%, transparent 50.0%);
# }
# #T_26eac_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 100.0%, transparent 100.0%);
# }
# #T_26eac_row2_col0, #T_26eac_row6_col0 {
#   width: 10em;
#   height: 80%;
# }
# #T_26eac_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 100.0%, transparent 100.0%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF420E 100.0%, transparent 100.0%);
# }
# #T_26eac_row4_col0 {
#   width: 10em;
#   height: 80%;
#   width: 10em;
#   height: 80%;
# }
# #T_26eac_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 70.5%, transparent 70.5%);
# }
# #T_26eac_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 82.7%, transparent 82.7%);
# }
# #T_26eac_row8_col0, #T_26eac_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 70.5%, transparent 70.5%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 70.5%, transparent 70.5%);
# }
# #T_26eac_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#1AAF54 29.5%, transparent 29.5%);
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 29.5%, transparent 29.5%);
# }
# </style>
# <table id="T_26eac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Scores</th>
#       <th class="col_heading level0 col1" >Details</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26eac_level0_row0" class="row_heading level0 row0" >AUC</th>
#       <td id="T_26eac_row0_col0" class="data row0 col0" >0.500</td>
#       <td id="T_26eac_row0_col1" class="data row0 col1" >Area under the ROC curve (true pos. rate vs false pos. rate); ranges from 0.5 (purely random classifier) to 1.0 (perfect classifier)</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row1" class="row_heading level0 row1" >True Positive Rate</th>
#       <td id="T_26eac_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_26eac_row1_col1" class="data row1 col1" >100.0% of positive instances were correctly identified.; i.e. 141 "Good" labels were correctly identified out of 141 instances; a.k.a Sensitivity/Recall</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row2" class="row_heading level0 row2" >True Negative Rate</th>
#       <td id="T_26eac_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_26eac_row2_col1" class="data row2 col1" >0.0% of negative instances were correctly identified.; i.e. 0 "Bad" labels were correctly identified out of 59 instances</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row3" class="row_heading level0 row3" >False Positive Rate</th>
#       <td id="T_26eac_row3_col0" class="data row3 col0" >1.000</td>
#       <td id="T_26eac_row3_col1" class="data row3 col1" >100.0% of negative instances were incorrectly identified as positive; i.e. 59 "Bad" labels were incorrectly identified as "Good", out of 59 instances</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row4" class="row_heading level0 row4" >False Negative Rate</th>
#       <td id="T_26eac_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_26eac_row4_col1" class="data row4 col1" >0.0% of positive instances were incorrectly identified as negative; i.e. 0 "Good" labels were incorrectly identified as "Bad", out of 141 instances</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row5" class="row_heading level0 row5" >Positive Predictive Value</th>
#       <td id="T_26eac_row5_col0" class="data row5 col0" >0.705</td>
#       <td id="T_26eac_row5_col1" class="data row5 col1" >When the model claims an instance is positive, it is correct 70.5% of the time; i.e. out of the 200 times the model predicted "Good", it was correct 141 times; a.k.a precision</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row6" class="row_heading level0 row6" >Negative Predictive Value</th>
#       <td id="T_26eac_row6_col0" class="data row6 col0" >0.000</td>
#       <td id="T_26eac_row6_col1" class="data row6 col1" >When the model claims an instance is negative, it is correct 0.0% of the time; i.e. out of the 0 times the model predicted "Bad", it was correct 0 times</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row7" class="row_heading level0 row7" >F1 Score</th>
#       <td id="T_26eac_row7_col0" class="data row7 col0" >0.827</td>
#       <td id="T_26eac_row7_col1" class="data row7 col1" >The F1 score can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0.</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row8" class="row_heading level0 row8" >Accuracy</th>
#       <td id="T_26eac_row8_col0" class="data row8 col0" >0.705</td>
#       <td id="T_26eac_row8_col1" class="data row8 col1" >70.5% of instances were correctly identified</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row9" class="row_heading level0 row9" >Error Rate</th>
#       <td id="T_26eac_row9_col0" class="data row9 col0" >0.295</td>
#       <td id="T_26eac_row9_col1" class="data row9 col1" >29.5% of instances were incorrectly identified</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row10" class="row_heading level0 row10" >% Positive</th>
#       <td id="T_26eac_row10_col0" class="data row10 col0" >0.705</td>
#       <td id="T_26eac_row10_col1" class="data row10 col1" >70.5% of the data are positive; i.e. out of 200 total observations; 141 are labeled as "Good"</td>
#     </tr>
#     <tr>
#       <th id="T_26eac_level0_row11" class="row_heading level0 row11" >Total Observations</th>
#       <td id="T_26eac_row11_col0" class="data row11 col0" >200</td>
#       <td id="T_26eac_row11_col1" class="data row11 col1" >There are 200 total observations; i.e. sample size</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluator.plot_auc_curve()
plt.grid()

# %%
evaluator.plot_threshold_curves()
plt.grid()

# %%
evaluator.plot_precision_recall_tradeoff(score_threshold_range=(0.4, 0.95))
plt.grid()

# %%
evaluator.calculate_lift_gain(return_style=True, include_all_info=True)
# Out:
# <style type="text/css">
# #T_4e9e7_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 7.0%, transparent 7.0%);
# }
# #T_4e9e7_row0_col4, #T_4e9e7_row1_col4, #T_4e9e7_row2_col4, #T_4e9e7_row19_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 100.0%, transparent 100.0%);
# }
# #T_4e9e7_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 14.0%, transparent 14.0%);
# }
# #T_4e9e7_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 21.0%, transparent 21.0%);
# }
# #T_4e9e7_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 28.0%, transparent 28.0%);
# }
# #T_4e9e7_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 90.5%, transparent 90.5%);
# }
# #T_4e9e7_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 33.0%, transparent 33.0%);
# }
# #T_4e9e7_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 71.4%, transparent 71.4%);
# }
# #T_4e9e7_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 40.0%, transparent 40.0%);
# }
# #T_4e9e7_row5_col4, #T_4e9e7_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 76.2%, transparent 76.2%);
# }
# #T_4e9e7_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 46.0%, transparent 46.0%);
# }
# #T_4e9e7_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 52.0%, transparent 52.0%);
# }
# #T_4e9e7_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 73.8%, transparent 73.8%);
# }
# #T_4e9e7_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 57.0%, transparent 57.0%);
# }
# #T_4e9e7_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 66.7%, transparent 66.7%);
# }
# #T_4e9e7_row9_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 63.0%, transparent 63.0%);
# }
# #T_4e9e7_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 61.9%, transparent 61.9%);
# }
# #T_4e9e7_row10_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 68.0%, transparent 68.0%);
# }
# #T_4e9e7_row10_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 57.1%, transparent 57.1%);
# }
# #T_4e9e7_row11_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 73.0%, transparent 73.0%);
# }
# #T_4e9e7_row11_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 52.4%, transparent 52.4%);
# }
# #T_4e9e7_row12_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 78.0%, transparent 78.0%);
# }
# #T_4e9e7_row12_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 47.6%, transparent 47.6%);
# }
# #T_4e9e7_row13_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 82.0%, transparent 82.0%);
# }
# #T_4e9e7_row13_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 40.5%, transparent 40.5%);
# }
# #T_4e9e7_row14_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 86.0%, transparent 86.0%);
# }
# #T_4e9e7_row14_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 33.3%, transparent 33.3%);
# }
# #T_4e9e7_row15_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 89.0%, transparent 89.0%);
# }
# #T_4e9e7_row15_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 28.6%, transparent 28.6%);
# }
# #T_4e9e7_row16_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 93.0%, transparent 93.0%);
# }
# #T_4e9e7_row16_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 21.4%, transparent 21.4%);
# }
# #T_4e9e7_row17_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 95.0%, transparent 95.0%);
# }
# #T_4e9e7_row17_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 14.3%, transparent 14.3%);
# }
# #T_4e9e7_row18_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 99.0%, transparent 99.0%);
# }
# #T_4e9e7_row18_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7AA9CF 9.5%, transparent 9.5%);
# }
# #T_4e9e7_row19_col4 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_4e9e7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" ># of Obs.</th>
#       <th class="col_heading level0 col1" ># of Pos. Events</th>
#       <th class="col_heading level0 col2" >Cumul. Pos. Events</th>
#       <th class="col_heading level0 col3" >Gain</th>
#       <th class="col_heading level0 col4" >Lift</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Percentile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e9e7_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_4e9e7_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_4e9e7_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_4e9e7_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_4e9e7_row0_col3" class="data row0 col3" >0.07</td>
#       <td id="T_4e9e7_row0_col4" class="data row0 col4" >1.42</td>
#     </tr>
#     <tr>
#       <th id="T_4e9e7_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_4e9e7_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_4e9e7_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_4e9e7_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_4e9e7_row1_col3" class="data row1 col3" >0.14</td>
#       <td id="T_4e9e7_row1_col4" class="data row1 col4" >1.42</td>
#     </tr>
#     <tr>
#       <th id="T_4e9e7_level0_row2" class="row_heading level0 row2" >15</th>
#       <td id="T_4e9e7_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_4e9e7_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_4e9e7_row2_col2" class="data row2 col2" >30</td>
#       <td id="T_4e9e7_row2_col3" class="data row2 col3" >0.21</td>
#       <td id="T_4e9e7_row2_col4" class="data row2 col4" >1.42</td>
#     </tr>
#     <tr>
#       <th id="T_4e9e7_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_4e9e7_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_4e9e7_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_4e9e7_row3_col2" class="data row3 col2" >39</td>
#       <td id="T_4e9e7_row3_col3" class="data row3 col3" >0.28</td>
#       <td id="T_4e9e7_row3_col4" class="data row3 col4" >1.38</td>
#     </tr>
#     <tr>
#       <th id="T_4e9e7_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_4e9e7_row4_col0" class="data row4 col0" >10</td>
#       <td id="T_4e9e7_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_4e9e7_row4_col2" class="data row4 col2" >46</td>
#       <td id="T_4e9e7_row4_col3" class="data row4 col3" >0.33</td>
#       <td id="T_4e9e7_row4_col4" class="data row4 col4" >1.30</td>
#     </tr>
#     <tr>
#       <th id="T_4e9e7_level0_row5" class="row_heading level0 row5" >30</th>
#       <td id="T_4e9e7_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_4e9e7_row5_col1" class="data row5 col1" >10</td>
#       <td id="T_4e9e7_row5_col2" class="data row5 col2" >56</td>
#       <td id="T_4e9e7_row5_col3" class="data row5 col3" >0.40</td>
#       <td id="T_4e9e7_row5_col4" class="data row5 col4" >1.32</td>
#     </tr>
#     <tr>
#       <th id="T_4e9e7_level0_row6" class="row_heading level0 row6" >35</th>
#       <td id="T_4e9e7_row6_col0" class="data row6 col0" >10</td>
#       <td id="T_4e9e7_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_4e9e7_row6_

# %%
del predicted_scores

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# todo: how to get features names out of final_estimator?

# %%
del numeric_pipeline
del non_numeric_pipeline
del transformations_pipeline
del random_forest_model
del full_pipeline

# %% [markdown]
# ## Build Final Model

# %%
grid_search.best_params_
# Out:
# {'model__max_features': 2,
#  'model__n_estimators': 500,
#  'prep__non_numeric__encoder__transformer': OneHotEncoder(),
#  'prep__numeric__impute__transformer': SimpleImputer(),
#  'prep__numeric__scaling__transformer': MinMaxScaler()}

# %%
bayes_search.best_params_
# Out:
# OrderedDict([('model__max_features', 0.01),
#              ('model__n_estimators', 1824),
#              ('prep__non_numeric__encoder__transformer',
#               CustomOrdinalEncoder()),
#              ('prep__numeric__impute__transformer', SimpleImputer()),
#              ('prep__numeric__scaling__transformer', MinMaxScaler())])

# %%
numeric_pipeline = Pipeline([
    ('impute', SimpleImputer()),
    ('scale', MinMaxScaler()),
])

# %%
non_numeric_pipeline = Pipeline([
    ('encoder', OneHotEncoder()),
])

# %%
transformations_pipeline = ColumnTransformer([
    ('numeric_pipeline', numeric_pipeline, numeric_columns),
    ('non_numeric_pipeline', non_numeric_pipeline, non_numeric_columns)
])

# %%
random_forest_model = RandomForestClassifier(random_state=42, max_features=10, n_estimators=500)

# %%
full_pipeline = Pipeline([
    ('preparation', transformations_pipeline),
    ('model', random_forest_model)
])

# %%
full_pipeline.fit(X=X_full, y=y_full)
# Out:
# Pipeline(steps=[('preparation',
#                  ColumnTransformer(transformers=[('numeric_pipeline',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    MinMaxScaler())]),
#                                                   ['duration', 'credit_amount',
#                                                    'installment_commitment',
#                                                    'residence_since', 'age',
#                                                    'existing_credits',
#                                                    'num_dependents']),
#                                                  ('non_numeric_pipeline',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder())]),
#                                                   ['checking_status',
#                                                    'credit_history', 'purpose',
#                                                    'savings_status',
#                                                    'employment',
#                                                    'personal_status',
#                                                    'other_parties',
#                                                    'property_magnitude',
#                                                    'other_payment_plans',
#                                                    'housing', 'job',
#                                                    'own_telephone',
#                                                    'foreign_worker'])])),
#                 ('model',
#                  RandomForestClassifier(max_features=10, n_estimators=500,
#                                         random_state=42))])

# %%
final_model = full_pipeline.named_steps['model']
final_model
# Out:
# RandomForestClassifier(max_features=10, n_estimators=500, random_state=42)

# %% [markdown]
# https://stackoverflow.com/questions/54646709/sklearn-pipeline-get-feature-names-after-onehotencode-in-columntransformer
#
# ```
# clf.named_steps['preparation'].transformers_[1][1]\
#    .named_steps['onehot'].get_feature_names(categorical_features)
# ```

# %%
new_non_numeric_columns = full_pipeline.named_steps['preparation'].transformers_[1][1].named_steps['encoder'].get_feature_names_out()
new_non_numeric_columns = list(new_non_numeric_columns)

# %%
len(new_non_numeric_columns)
# Out:
# 55

# %%
len(final_model.feature_importances_)
# Out:
# 62

# %%
final_column_names = numeric_columns + new_non_numeric_columns

# %%
pd.DataFrame({
    'importance (final)': final_model.feature_importances_,
    'importance (cross val)': grid_search.best_estimator_._final_estimator.feature_importances_
    
}, index=final_column_names).\
sort_values(by='importance (final)', ascending=False).\
style.bar(color=hlp.color.GRAY, vmin=0)
# Out:
# <style type="text/css">
# #T_179c0_row0_col0, #T_179c0_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 100.0%, transparent 100.0%);
# }
# #T_179c0_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 81.3%, transparent 81.3%);
# }
# #T_179c0_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 88.1%, transparent 88.1%);
# }
# #T_179c0_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 72.1%, transparent 72.1%);
# }
# #T_179c0_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 78.2%, transparent 78.2%);
# }
# #T_179c0_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 45.6%, transparent 45.6%);
# }
# #T_179c0_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 41.3%, transparent 41.3%);
# }
# #T_179c0_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 39.4%, transparent 39.4%);
# }
# #T_179c0_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 40.4%, transparent 40.4%);
# }
# #T_179c0_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 33.5%, transparent 33.5%);
# }
# #T_179c0_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 46.5%, transparent 46.5%);
# }
# #T_179c0_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 31.6%, transparent 31.6%);
# }
# #T_179c0_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 45.5%, transparent 45.5%);
# }
# #T_179c0_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 21.4%, transparent 21.4%);
# }
# #T_179c0_row7_col1, #T_179c0_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 24.8%, transparent 24.8%);
# }
# #T_179c0_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 20.0%, transparent 20.0%);
# }
# #T_179c0_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 18.0%, transparent 18.0%);
# }
# #T_179c0_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 22.7%, transparent 22.7%);
# }
# #T_179c0_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 17.3%, transparent 17.3%);
# }
# #T_179c0_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 24.2%, transparent 24.2%);
# }
# #T_179c0_row11_col0, #T_179c0_row12_col0, #T_179c0_row21_col1, #T_179c0_row31_col1, #T_179c0_row35_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 15.8%, transparent 15.8%);
# }
# #T_179c0_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 26.0%, transparent 26.0%);
# }
# #T_179c0_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 20.6%, transparent 20.6%);
# }
# #T_179c0_row13_col0, #T_179c0_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 14.5%, transparent 14.5%);
# }
# #T_179c0_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 19.9%, transparent 19.9%);
# }
# #T_179c0_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 21.7%, transparent 21.7%);
# }
# #T_179c0_row15_col0, #T_179c0_row33_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 14.3%, transparent 14.3%);
# }
# #T_179c0_row15_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 20.9%, transparent 20.9%);
# }
# #T_179c0_row16_col0, #T_179c0_row17_col0, #T_179c0_row37_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 13.9%, transparent 13.9%);
# }
# #T_179c0_row16_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 20.3%, transparent 20.3%);
# }
# #T_179c0_row17_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 20.4%, transparent 20.4%);
# }
# #T_179c0_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 13.4%, transparent 13.4%);
# }
# #T_179c0_row18_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 23.0%, transparent 23.0%);
# }
# #T_179c0_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 13.3%, transparent 13.3%);
# }
# #T_179c0_row19_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 20.1%, transparent 20.1%);
# }
# #T_179c0_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 13.2%, transparent 13.2%);
# }
# #T_179c0_row20_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 17.7%, transparent 17.7%);
# }
# #T_179c0_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 12.9%, transparent 12.9%);
# }
# #T_179c0_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 12.8%, transparent 12.8%);
# }
# #T_179c0_row22_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 16.4%, transparent 16.4%);
# }
# #T_179c0_row23_col0, #T_179c0_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 12.6%, transparent 12.6%);
# }
# #T_179c0_row23_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 17.4%, transparent 17.4%);
# }
# #T_179c0_row24_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 17.2%, transparent 17.2%);
# }
# #T_179c0_row25_col0, #T_179c0_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 12.4%, transparent 12.4%);
# }
# #T_179c0_row25_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 19.4%, transparent 19.4%);
# }
# #T_179c0_row26_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 22.0%, transparent 22.0%);
# }
# #T_179c0_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 12.3%, transparent 12.3%);
# }
# #T_179c0_row27_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 20.7%, transparent 20.7%);
# }
# #T_179c0_row28_col0, #T_179c0_row36_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 11.8%, transparent 11.8%);
# }
# #T_179c0_row28_col1, #T_179c0_row29_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 19.8%, transparent 19.8%);
# }
# #T_179c0_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 11.7%, transparent 11.7%);
# }
# #T_179c0_row30_col0, #T_179c0_row45_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 11.6%, transparent 11.6%);
# }
# #T_179c0_row30_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 14.8%, transparent 14.8%);
# }
# #T_179c0_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 11.4%, transparent 11.4%);
# }
# #T_179c0_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 11.2%, transparent 11.2%);
# }
# #T_179c0_row32_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 15.1%, transparent 15.1%);
# }
# #T_179c0_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 10.8%, transparent 10.8%);
# }
# #T_179c0_row34_col0, #T_179c0_row44_col1, #T_179c0_row46_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 10.7%, transparent 10.7%);
# }
# #T_179c0_row34_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 16.6%, transparent 16.6%);
# }
# #T_179c0_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 10.1%, transparent 10.1%);
# }
# #T_179c0_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 9.9%, transparent 9.9%);
# }
# #T_179c0_row37

# %% [markdown]
# # TODO

# %% [markdown]
# - get feature importance for model that has various transformations (would have to build pipeline manually based on selected transformers since transformers are being tuned via grid-search)
#     - https://towardsdatascience.com/how-to-get-feature-importances-from-any-sklearn-pipeline-167a19f1214
#     - https://stackoverflow.com/questions/38787612/how-to-extract-feature-importances-from-an-sklearn-pipeline
#
# ```
# grid_search.best_estimator_._final_estimator.feature_importances_
# grid_search.best_estimator_._final_estimator.feature_importances_.shape
# ```
#
# right now we can get importances but can't get feature names since it is being

# %%
#grid_search.best_estimator_.named_steps['preparation'].transformers[1][1].named_steps['encoder'].transformer.get_feature_names()

# %%
grid_search.best_estimator_._final_estimator.feature_importances_
# Out:
# array([0.06392319, 0.08176671, 0.0380507 , 0.03722161, 0.07205391,
#        0.02128217, 0.01135315, 0.01975279, 0.03300944, 0.00656691,
#        0.03380932, 0.00601217, 0.00968149, 0.02024632, 0.00926076,
#        0.01689088, 0.01231891, 0.01122847, 0.0028823 , 0.00874858,
#        0.01408273, 0.01852644, 0.00232178, 0.01794846, 0.00393875,
#        0.0012857 , 0.0097917 , 0.00945918, 0.00701141, 0.0202496 ,
#        0.0060604 , 0.01293276, 0.01671606, 0.01361385, 0.01446542,
#        0.01615652, 0.00922622, 0.01661636, 0.00602843, 0.00878087,
#        0.01772468, 0.00559852, 0.00596786, 0.00940453, 0.01641875,
#        0.01420544, 0.01289265, 0.01627603, 0.01343604, 0.01682256,
#        0.00647033, 0.00979669, 0.01880648, 0.01291542, 0.01210869,
#        0.01706706, 0.00274172, 0.0117306 , 0.01620724, 0.0158297 ,
#        0.00347457, 0.00283206])

# %% [markdown]
# - future importance
#     - https://www.kaggle.com/general/175075
#         - LOFO (Leave one feature out) for feature importance.
#     - https://explained.ai/rf-importance/

# %% [markdown]
# # Sandbox

# %% [markdown]
# ## Fit Regression on Cross Validation

# %%
bayes_search_df = bayes_search_parsed.results
bayes_search_df = bayes_search_df.drop(columns=['roc_auc 95CI.LO', 'roc_auc 95CI.HI'])
bayes_search_df.head()
# Out:
#     roc_auc Mean  max_features  n_estimators                 encoder  \
# 28      0.775353      0.010000          1824  CustomOrdinalEncoder()
# 20      0.768999      0.010000          5000  CustomOrdinalEncoder()
# 23      0.765502      0.021853           281  CustomOrdinalEncoder()
# 15      0.765128      0.120662          1405  CustomOrdinalEncoder()
# 9       0.762933      0.013558          4098  CustomOrdinalEncoder()
#
#             imputer            scaler
# 28  SimpleImputer()    MinMaxScaler()
# 20  SimpleImputer()    MinMaxScaler()
# 23  SimpleImputer()  StandardScaler()
# 15  SimpleImputer()  StandardScaler()
# 9   SimpleImputer()  StandardScaler()

# %%
cleaned_column_names = [''.join(e for e in x.replace(' ', '_') if e == '_' or e.isalnum()) for x in bayes_search_df.columns.tolist()]
cleaned_column_names = dict(zip(bayes_search_df.columns.tolist(), cleaned_column_names))
bayes_search_df.rename(columns=cleaned_column_names, inplace=True)

del cleaned_column_names

bayes_search_df.head()
# Out:
#     roc_auc_Mean  max_features  n_estimators                 encoder  \
# 28      0.775353      0.010000          1824  CustomOrdinalEncoder()
# 20      0.768999      0.010000          5000  CustomOrdinalEncoder()
# 23      0.765502      0.021853           281  CustomOrdinalEncoder()
# 15      0.765128      0.120662          1405  CustomOrdinalEncoder()
# 9       0.762933      0.013558          4098  CustomOrdinalEncoder()
#
#             imputer            scaler
# 28  SimpleImputer()    MinMaxScaler()
# 20  SimpleImputer()    MinMaxScaler()
# 23  SimpleImputer()  StandardScaler()
# 15  SimpleImputer()  StandardScaler()
# 9   SimpleImputer()  StandardScaler()

# %%
#bayes_search_df = bayes_search_df[['roc_auc_Mean', 'model__max_features', 'model__n_estimators']]
bayes_search_df
# Out:
#     roc_auc_Mean  max_features  n_estimators                 encoder  \
# 28      0.775353      0.010000          1824  CustomOrdinalEncoder()
# 20      0.768999      0.010000          5000  CustomOrdinalEncoder()
# 23      0.765502      0.021853           281  CustomOrdinalEncoder()
# 15      0.765128      0.120662          1405  CustomOrdinalEncoder()
# 9       0.762933      0.013558          4098  CustomOrdinalEncoder()
# 27      0.762422      0.010000          1948  CustomOrdinalEncoder()
# 19      0.761724      0.177104           557  CustomOrdinalEncoder()
# 14      0.759971      0.477581          1554  CustomOrdinalEncoder()
# 26      0.759897      0.017556          4995         OneHotEncoder()
# 25      0.759590      0.010249          3561         OneHotEncoder()
# 11      0.759077      0.268499          4008  CustomOrdinalEncoder()
# 18      0.758795      0.010000          2709  CustomOrdinalEncoder()
# 7       0.751457      0.542535          4604         OneHotEncoder()
# 22      0.751365      0.010000          4331  CustomOrdinalEncoder()
# 13      0.750094      0.745836          1858  CustomOrdinalEncoder()
# 2       0.749890      0.445936          4598         OneHotEncoder()
# 4       0.749055      0.793562          2218  CustomOrdinalEncoder()
# 5       0.749031      0.729347          4700         OneHotEncoder()
# 24      0.748484      0.016282            57  CustomOrdinalEncoder()
# 1       0.747332      0.830641          4422         OneHotEncoder()
# 8       0.746934      0.946368          3518  CustomOrdinalEncoder()
# 10      0.744760      0.391470          4309  CustomOrdinalEncoder()
# 0       0.743784      0.411902          3652  CustomOrdinalEncoder()
# 12      0.742658      0.682489          2634  CustomOrdinalEncoder()
# 21      0.740690      0.990000            50         OneHotEncoder()
# 29      0.739572      0.987060          4942  CustomOrdinalEncoder()
# 6       0.739555      0.614738          3888         OneHotEncoder()
# 16      0.738836      0.884065          1261  CustomOrdinalEncoder()
# 3       0.738530      0.806148           901  CustomOrdinalEncoder()
# 17      0.731019      0.028835            50         OneHotEncoder()
#
#             imputer            scaler
# 28  SimpleImputer()    MinMaxScaler()
# 20  SimpleImputer()    MinMaxScaler()
# 23  SimpleImputer()  StandardScaler()
# 15  SimpleImputer()  StandardScaler()
# 9   SimpleImputer()  StandardScaler()
# 27  SimpleImputer()  StandardScaler()
# 19  SimpleImputer()    MinMaxScaler()
# 14  SimpleImputer()    MinMaxScaler()
# 26  SimpleImputer()  StandardScaler()
# 25  SimpleImputer()    MinMaxScaler()
# 11  SimpleImputer()    MinMaxScaler()
# 18  SimpleImputer()    MinMaxScaler()
# 7   SimpleImputer()    MinMaxScaler()
# 22  SimpleImputer()    MinMaxScaler()
# 13  SimpleImputer()  StandardScaler()
# 2   SimpleImputer()    MinMaxScaler()
# 4   SimpleImputer()  StandardScaler()
# 5   SimpleImputer()  StandardScaler()
# 24  SimpleImputer()  StandardScaler()
# 1   SimpleImputer()  StandardScaler()
# 8   SimpleImputer()    MinMaxScaler()
# 10  SimpleImputer()  StandardScaler()
# 0   SimpleImputer()  StandardScaler()
# 12  SimpleImputer()    MinMaxScaler()
# 21  SimpleImputer()    MinMaxScaler()
# 29  SimpleImputer()    MinMaxScaler()
# 6   SimpleImputer()  StandardScaler()
# 16  SimpleImputer()    MinMaxScaler()
# 3   SimpleImputer()  StandardScaler()
# 17  SimpleImputer()    MinMaxScaler()

# %%
import statsmodels.formula.api as smf

y_column = 'roc_auc_Mean'
X_columns = bayes_search_df.columns.tolist()
X_columns.remove(y_column)
X_columns = hlp.string.collapse(X_columns, separate=" + ", surround="")

formula = f"{y_column} ~ {X_columns}"
print(formula)
model = smf.ols(formula=formula, data = bayes_search_df)
results = model.fit()
print(results.summary())
# Out:
# roc_auc_Mean ~ max_features + n_estimators + encoder + imputer + scaler
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           roc_auc_Mean   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     5.874
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):            0.00178
# Time:                        11:44:11   Log-Likelihood:                 104.02
# No. Observations:                  30   AIC:                            -198.0
# Df Residuals:                      25   BIC:                            -191.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.7585      0.004    208.733      0.000       0.751       0.766
# encoder[T.OneHotEncoder()]    -0.0056      0.003     -1.632      0.115      -0.013       0.001
# scaler[T.StandardScaler()]    -0.0006      0.003     -0.209      0.836      -0.007       0.006
# max_features                  -0.0183      0.004     -4.330      0.000      -0.027      -0.010
# n_estimators                 1.04e-06   9.31e-07      1.117      0.275   -8.77e-07    2.96e-06
# ==============================================================================
# Omnibus:                        3.925   Durbin-Watson:                   1.108
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.571
# Skew:                          -0.685   Prob(JB):                        0.277
# Kurtosis:                       3.421   Cond. No.                     1.03e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#scaler.fit_transform(bayes_search_df)

numeric_columns = hlp.pandas.get_numeric_columns(bayes_search_df)
non_numeric_columns = hlp.pandas.get_non_numeric_columns(bayes_search_df)

print(numeric_columns)
print(non_numeric_columns)

numeric_pipeline = Pipeline([
    ('scaling', StandardScaler()),
])

transformations_pipeline = ColumnTransformer([
    ('numeric_pipeline', numeric_pipeline, numeric_columns),
    ('non_numeric_pipeline', 'passthrough', non_numeric_columns)
])

bayes_search_transformed = transformations_pipeline.fit_transform(bayes_search_df)
bayes_search_transformed = pd.DataFrame(bayes_search_transformed,
                                        columns= numeric_columns + non_numeric_columns)
bayes_search_transformed
# Out:
# ['roc_auc_Mean', 'max_features', 'n_estimators']
# ['encoder', 'imputer', 'scaler']
#    roc_auc_Mean max_features n_estimators                 encoder  \
# 0       2.21328     -1.08282    -0.581305  CustomOrdinalEncoder()
# 1      1.608954     -1.08282     1.314657  CustomOrdinalEncoder()
# 2      1.276375    -1.049923    -1.502423  CustomOrdinalEncoder()
# 3      1.240862    -0.775684    -0.831434  CustomOrdinalEncoder()
# 4      1.032114    -1.072946     0.776195  CustomOrdinalEncoder()
# 5      0.983456     -1.08282    -0.507281  CustomOrdinalEncoder()
# 6      0.917063    -0.619032    -1.337661  CustomOrdinalEncoder()
# 7      0.750376     0.214926    -0.742486  CustomOrdinalEncoder()
# 8      0.743296     -1.06185     1.311673         OneHotEncoder()
# 9      0.714138    -1.082129     0.455624         OneHotEncoder()
# 10     0.665327    -0.365369     0.722468  CustomOrdinalEncoder()
# 11     0.638474     -1.08282    -0.052991  CustomOrdinalEncoder()
# 12    -0.059405     0.395203     1.078259         OneHotEncoder()
# 13    -0.068074     -1.08282     0.915287  CustomOrdinalEncoder()
# 14    -0.189005     0.959454    -0.561008  CustomOrdinalEncoder()
# 15    -0.208385     0.127097     1.074677         OneHotEncoder()
# 16    -0.287802     1.091916    -0.346101  CustomOrdinalEncoder()
# 17    -0.290044     0.913691     1.135568         OneHotEncoder()
# 18    -0.342144    -1.065385    -1.636143  CustomOrdinalEncoder()
# 19    -0.451693     1.194825     0.969611         OneHotEncoder()
# 20    -0.489563     1.516022     0.429954  CustomOrdinalEncoder()
# 21    -0.696303    -0.024071     0.902154  CustomOrdinalEncoder()
# 22    -0.789079     0.032637     0.509948  CustomOrdinalEncoder()
# 23    -0.896157     0.783637    -0.097763  CustomOrdinalEncoder()
# 24    -1.083386     1.637119    -1.640322         OneHotEncoder()
# 25    -1.189722      1.62896     1.280033  CustomOrdinalEncoder()
# 26    -1.191272     0.595598     0.650832         OneHotEncoder()
# 27    -1.259669     1.343101    -0.917397  CustomOrdinalEncoder()
# 28    -1.288834     1.126847    -1.132304  CustomOrdinalEncoder()
# 29    -2.003178    -1.030544    -1.640322         OneHotEncoder()
#
#             imputer            scaler
# 0   SimpleImputer()    MinMaxScaler()
# 1   SimpleImputer()    MinMaxScaler()
# 2   SimpleImputer()  StandardScaler()
# 3   SimpleImputer()  StandardScaler()
# 4   SimpleImputer()  StandardScaler()
# 5   SimpleImputer()  StandardScaler()
# 6   SimpleImputer()    MinMaxScaler()
# 7   SimpleImputer()    MinMaxScaler()
# 8   SimpleImputer()  StandardScaler()
# 9   SimpleImputer()    MinMaxScaler()
# 10  SimpleImputer()    MinMaxScaler()
# 11  SimpleImputer()    MinMaxScaler()
# 12  SimpleImputer()    MinMaxScaler()
# 13  SimpleImputer()    MinMaxScaler()
# 14  SimpleImputer()  StandardScaler()
# 15  SimpleImputer()    MinMaxScaler()
# 16  SimpleImputer()  StandardScaler()
# 17  SimpleImputer()  StandardScaler()
# 18  SimpleImputer()  StandardScaler()
# 19  SimpleImputer()  StandardScaler()
# 20  SimpleImputer()    MinMaxScaler()
# 21  SimpleImputer()  StandardScaler()
# 22  SimpleImputer()  StandardScaler()
# 23  SimpleImputer()    MinMaxScaler()
# 24  SimpleImputer()    MinMaxScaler()
# 25  SimpleImputer()    MinMaxScaler()
# 26  SimpleImputer()  StandardScaler()
# 27  SimpleImputer()    MinMaxScaler()
# 28  SimpleImputer()  StandardScaler()
# 29  SimpleImputer()    MinMaxScaler()

# %%
bayes_search_transformed['roc_auc_Mean'].hist()
# Out:
# <AxesSubplot:>

# %%
bayes_search_transformed['roc_auc_Mean'] = bayes_search_transformed['roc_auc_Mean'].astype('float')
bayes_search_transformed['max_features'] = bayes_search_transformed['max_features'].astype('float')
bayes_search_transformed['n_estimators'] = bayes_search_transformed['n_estimators'].astype('float')

# %%
print(formula)
model = smf.ols(formula=formula,
                data = bayes_search_transformed)
results = model.fit()
print(results.summary())
# Out:
# roc_auc_Mean ~ max_features + n_estimators + encoder + imputer + scaler
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           roc_auc_Mean   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     5.874
# Date:                Sat, 04 Dec 2021   Prob (F-statistic):            0.00178
# Time:                        11:44:48   Log-Likelihood:                -32.629
# No. Observations:                  30   AIC:                             75.26
# Df Residuals:                      25   BIC:                             82.26
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1874      0.221      0.848      0.405      -0.268       0.643
# encoder[T.OneHotEncoder()]    -0.5311      0.325     -1.632      0.115      -1.201       0.139
# scaler[T.StandardScaler()]    -0.0602      0.288     -0.209      0.836      -0.653       0.533
# max_features                  -0.6269      0.145     -4.330      0.000      -0.925      -0.329
# n_estimators                   0.1657      0.148      1.117      0.275      -0.140       0.471
# ==============================================================================
# Omnibus:                        3.925   Durbin-Watson:                   1.108
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                2.571
# Skew:                          -0.685   Prob(JB):                        0.277
# Kurtosis:                       3.421   Cond. No.                         2.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
coefficients = results.params[results.params.index != 'Intercept']
#coefficients.reindex(coefficients.abs().sort_values(ascending=False).index).plot(kind='bar', figsize=(9, 6))
coefficients.plot(kind='bar', figsize=(9, 6))
# Out:
# <AxesSubplot:>

# %%
(1 - results.pvalues[results.pvalues.index != 'Intercept']).plot(kind='bar', figsize=(9, 6))
# Out:
# <AxesSubplot:>

# %%
coefficients = results.params[results.params.index != 'Intercept']
coefficients.reindex(coefficients.abs().sort_values(ascending=False).index).plot(kind='bar', figsize=(9, 6))
# Out:
# <AxesSubplot:>
