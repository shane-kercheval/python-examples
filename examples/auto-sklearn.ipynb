# %%
#import autosklearn.classification
from autosklearn.experimental.askl2 import AutoSklearn2Classifier
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics

X, y = sklearn.datasets.load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, random_state=1)
automl = AutoSklearn2Classifier(seed=1, n_jobs=8)
automl.fit(X_train, y_train)
y_hat = automl.predict(X_test)
print("Accuracy score", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /code/examples/auto-sklearn.ipynb Cell 1' in <cell line: 10>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d6578616d706c65732d6a7570797465722d31227d/code/examples/auto-sklearn.ipynb#ch0000000vscode-remote?line=7'>8</a> X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, random_state=1)
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d6578616d706c65732d6a7570797465722d31227d/code/examples/auto-sklearn.ipynb#ch0000000vscode-remote?line=8'>9</a> automl = AutoSklearn2Classifier()
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d6578616d706c65732d6a7570797465722d31227d/code/examples/auto-sklearn.ipynb#ch0000000vscode-remote?line=9'>10</a> automl.fit(X_train, y_train)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d6578616d706c65732d6a7570797465722d31227d/code/examples/auto-sklearn.ipynb#ch0000000vscode-remote?line=10'>11</a> y_hat = automl.predict(X_test)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d6578616d706c65732d6a7570797465722d31227d/code/examples/auto-sklearn.ipynb#ch0000000vscode-remote?line=11'>12</a> print("Accuracy score", sklearn.metrics.accuracy_score(y_test, y_hat))
#
# File /usr/local/lib/python3.9/site-packages/autosklearn/experimental/askl2.py:395, in AutoSklearn2Classifier.fit(self, X, y, X_test, y_test, metric, feat_type, dataset_name)
#     392     selector = pickle.load(fh)
#     394 metafeatures = pd.DataFrame({dataset_name: [X.shape[1], X.shape[0]]}).transpose()
# --> 395 selection = np.argmax(selector.predict(metafeatures))
#     396 automl_policy = strategies[selection]
#     398 setting = {
#     399     'RF_None_holdout_iterative_es_if': {
#     400         'resampling_strategy': 'holdout-iterative-fit',
#    (...)
#     436     }
#     437 }[automl_policy]
#
# File /usr/local/lib/python3.9/site-packages/autosklearn/experimental/selector.py:23, in AbstractSelector.predict(self, X, y)
#      22 def predict(self, X: pd.DataFrame, y: typing.Optional[pd.DataFrame] = None) -> pd.DataFrame:
# ---> 23     prediction = self._predict(X, y)
#      24     for col, series in prediction.iteritems():
#      25         assert series.dtype == float, (col, series)
#
# File /usr/local/lib/python3.9/site-packages/autosklearn/experimental/selector.py:330, in FallbackWrapper._predict(self, X, y)
#     328     prediction = self.selector.predict(X, y)
#     329 else:
# --> 330     prediction = self.selector.predict(X)
#     331 for task_id, x in X.iterrows():
#     332     counter = 0
#
# File /usr/local/lib/python3.9/site-packages/autosklearn/experimental/selector.py:23, in AbstractSelector.predict(self, X, y)
#      22 def predict(self, X: pd.DataFrame, y: typing.Optional[pd.DataFrame] = None) -> pd.DataFrame:
# ---> 23     prediction = self._predict(X, y)
#      24     for col, series in prediction.iteritems():
#      25         assert series.dtype == float, (col, series)
#
# File /usr/local/lib/python3.9/site-packages/autosklearn/experimental/selector.py:192, in OneVSOneSelector._predict(self, X, y)
#     190     for j in range(i + 1, len(self.target_indices)):
#     191         if self.models[i][j] is not None:
# --> 192             raw_predictions[(i, j)] = self.models[i][j].predict(X)
#     193             raw_probas[(i, j)] = self.models[i][j].predict_proba(X)
#     195 if len(raw_predictions) == 0:
#
# File /usr/local/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:630, in ForestClassifier.predict(self, X)
#     609 def predict(self, X):
#     610     """
#     611     Predict class for X.
#     612
#    (...)
#     628         The predicted classes.
#     629     """
# --> 630     proba = self.predict_proba(X)
#     632     if self.n_outputs_ == 1:
#     633         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File /usr/local/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:683, in ForestClassifier.predict_proba(self, X)
#     680 all_proba = [np.zeros((X.shape[0], j), dtype=np.float64)
#     681              for j in np.atleast_1d(self.n_classes_)]
#     682 lock = threading.Lock()
# --> 683 Parallel(n_jobs=n_jobs, verbose=self.verbose,
#     684          **_joblib_parallel_args(require="sharedmem"))(
#     685     delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#     686                                     lock)
#     687     for e in self.estimators_)
#     689 for proba in all_proba:
#     690     proba /= len(self.estimators_)
#
# File /usr/local/lib/python3.9/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File /usr/local/lib/python3.9/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File /usr/local/lib/python3.9/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File /usr/local/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /usr/local/lib/python3.9/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File /usr/local/lib/python3.9/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File /usr/local/lib/python3.9/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File /usr/local/lib/python3.9/site-packages/sklearn/utils/fixes.py:222, in _FuncWrapper.__call__(self, *args, **kwargs)
#     220 def __call__(self, *args, **kwargs):
#     221     with config_context(**self.config):
# --> 222         return self.function(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:467, in _accumulate_prediction(predict, X, out, lock)
#     460 def _accumulate_prediction(predict, X, out, lock):
#     461     """
#     462     This is a utility function for joblib's Parallel.
#     463
#     464     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     465     complains that it cannot pickle it when placed there.
#     466     """
# --> 467     prediction = predict(X, check_input=False)
#     468     with lock:
#     469         if len(out) == 1:
#
# File /usr/local/lib/python3.9/site-packages/sklearn/tree/_classes.py:942, in DecisionTreeClassifier.predict_proba(self, X, check_input)
#     940     normalizer = proba.sum(axis=1)[:, np.newaxis]
#     941     normalizer[normalizer == 0.0] = 1.0
# --> 942     proba /= normalizer
#     944     return proba
#     946 else:
#
# KeyboardInterrupt:

# %%
automl
