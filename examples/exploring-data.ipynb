# %%
#pip install --upgrade helpsk

# %%
import helpsk as hlp
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_openml
from vega_datasets import data
# data.list_datasets()
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
#https://www.openml.org/d/31
credit_g = fetch_openml('credit-g', version=1)
credit_data = credit_g['data']
credit_data['target'] = credit_g['target']
credit_data.shape
# Out:
# (1000, 21)

# %% [markdown]
# ## Create Missing Values

# %%
credit_data['duration'].iloc[0:10] = np.nan
credit_data['checking_status'].iloc[5:15] = np.nan
# Out:
# /Users/shanekercheval/opt/anaconda3/envs/python-examples/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# # Summary

# %%
hlp.pandas.numeric_summary(credit_data, return_style=True)
# Out:
# <style type="text/css">
# #T_5824e_row0_col1 {
#   background-color: #EBB13E;
# }
# #T_5824e_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#CF3721 1.0%, transparent 1.0%);
# }
# #T_5824e_row0_col4, #T_5824e_row1_col2, #T_5824e_row1_col4, #T_5824e_row2_col2, #T_5824e_row2_col4, #T_5824e_row3_col2, #T_5824e_row3_col4, #T_5824e_row4_col2, #T_5824e_row4_col4, #T_5824e_row5_col2, #T_5824e_row5_col4, #T_5824e_row6_col2, #T_5824e_row6_col4 {
#   width: 10em;
#   height: 80%;
# }
# #T_5824e_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 58.0%, transparent 58.0%);
# }
# #T_5824e_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 77.7%, transparent 77.7%);
# }
# #T_5824e_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 86.0%, transparent 86.0%);
# }
# #T_5824e_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 98.7%, transparent 98.7%);
# }
# #T_5824e_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 38.0%, transparent 38.0%);
# }
# #T_5824e_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.7%, #B4B7B9 36.7%, #B4B7B9 50.0%, transparent 50.0%);
# }
# #T_5824e_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 39.0%, transparent 39.0%);
# }
# #T_5824e_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 43.2%, #B4B7B9 43.2%, #B4B7B9 50.0%, transparent 50.0%);
# }
# #T_5824e_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 32.0%, transparent 32.0%);
# }
# #T_5824e_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 75.5%, transparent 75.5%);
# }
# #T_5824e_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 41.0%, transparent 41.0%);
# }
# #T_5824e_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 81.7%, transparent 81.7%);
# }
# #T_5824e_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 31.0%, transparent 31.0%);
# }
# #T_5824e_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #B4B7B9 50.0%, #B4B7B9 97.7%, transparent 97.7%);
# }
# </style>
# <table id="T_5824e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" ># of Non-Nulls</th>
#       <th class="col_heading level0 col1" ># of Nulls</th>
#       <th class="col_heading level0 col2" >% Nulls</th>
#       <th class="col_heading level0 col3" ># of Zeros</th>
#       <th class="col_heading level0 col4" >% Zeros</th>
#       <th class="col_heading level0 col5" >Mean</th>
#       <th class="col_heading level0 col6" >St Dev.</th>
#       <th class="col_heading level0 col7" >Coef of Var</th>
#       <th class="col_heading level0 col8" >Skewness</th>
#       <th class="col_heading level0 col9" >Kurtosis</th>
#       <th class="col_heading level0 col10" >Min</th>
#       <th class="col_heading level0 col11" >10%</th>
#       <th class="col_heading level0 col12" >25%</th>
#       <th class="col_heading level0 col13" >50%</th>
#       <th class="col_heading level0 col14" >75%</th>
#       <th class="col_heading level0 col15" >90%</th>
#       <th class="col_heading level0 col16" >Max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5824e_level0_row0" class="row_heading level0 row0" >duration</th>
#       <td id="T_5824e_row0_col0" class="data row0 col0" >990</td>
#       <td id="T_5824e_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_5824e_row0_col2" class="data row0 col2" >1.0%</td>
#       <td id="T_5824e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5824e_row0_col4" class="data row0 col4" >0.0%</td>
#       <td id="T_5824e_row0_col5" class="data row0 col5" >20.8</td>
#       <td id="T_5824e_row0_col6" class="data row0 col6" >12.0</td>
#       <td id="T_5824e_row0_col7" class="data row0 col7" >0.6</td>
#       <td id="T_5824e_row0_col8" class="data row0 col8" >1.1</td>
#       <td id="T_5824e_row0_col9" class="data row0 col9" >1.0</td>
#       <td id="T_5824e_row0_col10" class="data row0 col10" >4.0</td>
#       <td id="T_5824e_row0_col11" class="data row0 col11" >9.0</td>
#       <td id="T_5824e_row0_col12" class="data row0 col12" >12.0</td>
#       <td id="T_5824e_row0_col13" class="data row0 col13" >18.0</td>
#       <td id="T_5824e_row0_col14" class="data row0 col14" >24.0</td>
#       <td id="T_5824e_row0_col15" class="data row0 col15" >36.0</td>
#       <td id="T_5824e_row0_col16" class="data row0 col16" >72.0</td>
#     </tr>
#     <tr>
#       <th id="T_5824e_level0_row1" class="row_heading level0 row1" >credit_amount</th>
#       <td id="T_5824e_row1_col0" class="data row1 col0" >1,000</td>
#       <td id="T_5824e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_5824e_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_5824e_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_5824e_row1_col4" class="data row1 col4" >0.0%</td>
#       <td id="T_5824e_row1_col5" class="data row1 col5" >3,271.3</td>
#       <td id="T_5824e_row1_col6" class="data row1 col6" >2,822.7</td>
#       <td id="T_5824e_row1_col7" class="data row1 col7" >0.9</td>
#       <td id="T_5824e_row1_col8" class="data row1 col8" >1.9</td>
#       <td id="T_5824e_row1_col9" class="data row1 col9" >4.3</td>
#       <td id="T_5824e_row1_col10" class="data row1 col10" >250.0</td>
#       <td id="T_5824e_row1_col11" class="data row1 col11" >932.0</td>
#       <td id="T_5824e_row1_col12" class="data row1 col12" >1,365.5</td>
#       <td id="T_5824e_row1_col13" class="data row1 col13" >2,319.5</td>
#       <td id="T_5824e_row1_col14" class="data row1 col14" >3,972.2</td>
#       <td id="T_5824e_row1_col15" class="data row1 col15" >7,179.4</td>
#       <td id="T_5824e_row1_col16" class="data row1 col16" >18,424.0</td>
#     </tr>
#     <tr>
#       <th id="T_5824e_level0_row2" class="row_heading level0 row2" >installment_commitment</th>
#       <td id="T_5824e_row2_col0" class="data row2 col0" >1,000</td>
#       <td id="T_5824e_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_5824e_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_5824e_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_5824e_row2_col4" class="data row2 col4" >0.0%</td>
#       <td id="T_5824e_row2_col5" class="data row2 col5" >3.0</td>
#       <td id="T_5824e_row2_col6" class="data row2 col6" >1.1</td>
#       <td id="T_5824e_row2_col7" class="data row2 col7" >0.4</td>
#       <td id="T_5824e_row2_col8" class="data row2 col8" >-0.5</td>
#       <td id="T_5824e_row2_col9" class="data row2 col9" >-1.2</td>
#       <td id="T_5824e_row2_col10" class="data row2 col10" >1.0</td>
#       <td id="T_5824e_row2_col11" class="data row2 col11" >1.0</td>
#       <td id="T_5824e_row2_col12" class="data row2 col12" >2.0</td>
#       <td id="T_5824e_row2_col13" class="data row2 col13" >3.0</td>
#       <td id="T_5824e_row2_col14" class="data row2 col14" >4.0</td>
#       <td id="T_5824e_row2_col15" class="data row2 col15" >4.0</td>
#       <td id="T_5824e_row2_col16" class="data row2 col16" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_5824e_level0_row3" class="row_heading level0 row3" >residence_since</th>
#       <td id="T_5824e_row3_col0" class="data row3 col0" >1,000</td>
#       <td id="T_5824e_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_5824e_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_5824e_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_5824e_row3_col4" class="data row3 col4" >0.0%</td>
#       <td id="T_5824e_row3_col5" class="data row3 col5" >2.9</td>
#       <td id="T_5824e_row3_col6" class="data row3 col6" >1.1</td>
#       <td id="T_5824e_row3_col7" class="data row3 col7" >0.4</td>
#       <td id="T_5824e_row3_col8" class="data row3 col8" >-0

# %%
hlp.pandas.non_numeric_summary(credit_data, return_style=True)
# Out:
# <style type="text/css">
# #T_f00ee_row0_col1 {
#   background-color: #EBB13E;
# }
# #T_f00ee_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#CF3721 1.0%, transparent 1.0%);
# }
# #T_f00ee_row0_col5, #T_f00ee_row5_col5, #T_f00ee_row7_col5, #T_f00ee_row10_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.4%, transparent 0.4%);
# }
# #T_f00ee_row1_col2, #T_f00ee_row2_col2, #T_f00ee_row3_col2, #T_f00ee_row4_col2, #T_f00ee_row5_col2, #T_f00ee_row6_col2, #T_f00ee_row7_col2, #T_f00ee_row8_col2, #T_f00ee_row9_col2, #T_f00ee_row10_col2, #T_f00ee_row11_col2, #T_f00ee_row12_col2, #T_f00ee_row13_col2 {
#   width: 10em;
#   height: 80%;
# }
# #T_f00ee_row1_col5, #T_f00ee_row3_col5, #T_f00ee_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.5%, transparent 0.5%);
# }
# #T_f00ee_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 1.0%, transparent 1.0%);
# }
# #T_f00ee_row6_col5, #T_f00ee_row8_col5, #T_f00ee_row9_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.3%, transparent 0.3%);
# }
# #T_f00ee_row11_col5, #T_f00ee_row12_col5, #T_f00ee_row13_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.2%, transparent 0.2%);
# }
# </style>
# <table id="T_f00ee_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" ># of Non-Nulls</th>
#       <th class="col_heading level0 col1" ># of Nulls</th>
#       <th class="col_heading level0 col2" >% Nulls</th>
#       <th class="col_heading level0 col3" >Most Freq. Value</th>
#       <th class="col_heading level0 col4" ># of Unique</th>
#       <th class="col_heading level0 col5" >% Unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f00ee_level0_row0" class="row_heading level0 row0" >checking_status</th>
#       <td id="T_f00ee_row0_col0" class="data row0 col0" >990</td>
#       <td id="T_f00ee_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_f00ee_row0_col2" class="data row0 col2" >1.0%</td>
#       <td id="T_f00ee_row0_col3" class="data row0 col3" >no checking</td>
#       <td id="T_f00ee_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_f00ee_row0_col5" class="data row0 col5" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row1" class="row_heading level0 row1" >credit_history</th>
#       <td id="T_f00ee_row1_col0" class="data row1 col0" >1,000</td>
#       <td id="T_f00ee_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_f00ee_row1_col2" class="data row1 col2" >0.0%</td>
#       <td id="T_f00ee_row1_col3" class="data row1 col3" >existing paid</td>
#       <td id="T_f00ee_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_f00ee_row1_col5" class="data row1 col5" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row2" class="row_heading level0 row2" >purpose</th>
#       <td id="T_f00ee_row2_col0" class="data row2 col0" >1,000</td>
#       <td id="T_f00ee_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_f00ee_row2_col2" class="data row2 col2" >0.0%</td>
#       <td id="T_f00ee_row2_col3" class="data row2 col3" >radio/tv</td>
#       <td id="T_f00ee_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_f00ee_row2_col5" class="data row2 col5" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row3" class="row_heading level0 row3" >savings_status</th>
#       <td id="T_f00ee_row3_col0" class="data row3 col0" >1,000</td>
#       <td id="T_f00ee_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_f00ee_row3_col2" class="data row3 col2" >0.0%</td>
#       <td id="T_f00ee_row3_col3" class="data row3 col3" >&lt;100</td>
#       <td id="T_f00ee_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_f00ee_row3_col5" class="data row3 col5" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row4" class="row_heading level0 row4" >employment</th>
#       <td id="T_f00ee_row4_col0" class="data row4 col0" >1,000</td>
#       <td id="T_f00ee_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_f00ee_row4_col2" class="data row4 col2" >0.0%</td>
#       <td id="T_f00ee_row4_col3" class="data row4 col3" >1&lt;=X&lt;4</td>
#       <td id="T_f00ee_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_f00ee_row4_col5" class="data row4 col5" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row5" class="row_heading level0 row5" >personal_status</th>
#       <td id="T_f00ee_row5_col0" class="data row5 col0" >1,000</td>
#       <td id="T_f00ee_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_f00ee_row5_col2" class="data row5 col2" >0.0%</td>
#       <td id="T_f00ee_row5_col3" class="data row5 col3" >male single</td>
#       <td id="T_f00ee_row5_col4" class="data row5 col4" >4</td>
#       <td id="T_f00ee_row5_col5" class="data row5 col5" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row6" class="row_heading level0 row6" >other_parties</th>
#       <td id="T_f00ee_row6_col0" class="data row6 col0" >1,000</td>
#       <td id="T_f00ee_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_f00ee_row6_col2" class="data row6 col2" >0.0%</td>
#       <td id="T_f00ee_row6_col3" class="data row6 col3" >none</td>
#       <td id="T_f00ee_row6_col4" class="data row6 col4" >3</td>
#       <td id="T_f00ee_row6_col5" class="data row6 col5" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row7" class="row_heading level0 row7" >property_magnitude</th>
#       <td id="T_f00ee_row7_col0" class="data row7 col0" >1,000</td>
#       <td id="T_f00ee_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_f00ee_row7_col2" class="data row7 col2" >0.0%</td>
#       <td id="T_f00ee_row7_col3" class="data row7 col3" >car</td>
#       <td id="T_f00ee_row7_col4" class="data row7 col4" >4</td>
#       <td id="T_f00ee_row7_col5" class="data row7 col5" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row8" class="row_heading level0 row8" >other_payment_plans</th>
#       <td id="T_f00ee_row8_col0" class="data row8 col0" >1,000</td>
#       <td id="T_f00ee_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_f00ee_row8_col2" class="data row8 col2" >0.0%</td>
#       <td id="T_f00ee_row8_col3" class="data row8 col3" >none</td>
#       <td id="T_f00ee_row8_col4" class="data row8 col4" >3</td>
#       <td id="T_f00ee_row8_col5" class="data row8 col5" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row9" class="row_heading level0 row9" >housing</th>
#       <td id="T_f00ee_row9_col0" class="data row9 col0" >1,000</td>
#       <td id="T_f00ee_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_f00ee_row9_col2" class="data row9 col2" >0.0%</td>
#       <td id="T_f00ee_row9_col3" class="data row9 col3" >own</td>
#       <td id="T_f00ee_row9_col4" class="data row9 col4" >3</td>
#       <td id="T_f00ee_row9_col5" class="data row9 col5" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row10" class="row_heading level0 row10" >job</th>
#       <td id="T_f00ee_row10_col0" class="data row10 col0" >1,000</td>
#       <td id="T_f00ee_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_f00ee_row10_col2" class="data row10 col2" >0.0%</td>
#       <td id="T_f00ee_row10_col3" class="data row10 col3" >skilled</td>
#       <td id="T_f00ee_row10_col4" class="data row10 col4" >4</td>
#       <td id="T_f00ee_row10_col5" class="data row10 col5" >0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row11" class="row_heading level0 row11" >own_telephone</th>
#       <td id="T_f00ee_row11_col0" class="data row11 col0" >1,000</td>
#       <td id="T_f00ee_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_f00ee_row11_col2" class="data row11 col2" >0.0%</td>
#       <td id="T_f00ee_row11_col3" class="data row11 col3" >none</td>
#       <td id="T_f00ee_row11_col4" class="data row11 col4" >2</td>
#       <td id="T_f00ee_row11_col5" class="data row11 col5" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f00ee_level0_row12" class="row_heading level0 row12" >foreign_worker</th>
#       <td id="T_f00ee_row12_col0

# %%
hlp.pandas.count_groups(dataframe=credit_data,
                        group_1='target',
                        group_2='housing',
                        group_sum='credit_amount',
                        return_style=True)
# Out:
# <style type="text/css">
# #T_1be71_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 70.0%, transparent 70.0%);
# }
# #T_1be71_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 63.9%, transparent 63.9%);
# }
# #T_1be71_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 15.6%, transparent 15.6%);
# }
# #T_1be71_row0_col9, #T_1be71_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 14.7%, transparent 14.7%);
# }
# #T_1be71_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 75.3%, transparent 75.3%);
# }
# #T_1be71_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 71.6%, transparent 71.6%);
# }
# #T_1be71_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 9.1%, transparent 9.1%);
# }
# #T_1be71_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 13.7%, transparent 13.7%);
# }
# #T_1be71_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 30.0%, transparent 30.0%);
# }
# #T_1be71_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 36.1%, transparent 36.1%);
# }
# #T_1be71_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 23.3%, transparent 23.3%);
# }
# #T_1be71_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 21.2%, transparent 21.2%);
# }
# #T_1be71_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 62.0%, transparent 62.0%);
# }
# #T_1be71_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 58.2%, transparent 58.2%);
# }
# #T_1be71_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 20.6%, transparent 20.6%);
# }
# </style>
# <table id="T_1be71_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" colspan="5">target</th>
#       <th class="col_heading level0 col5" colspan="5">housing</th>
#     </tr>
#     <tr>
#       <th class="col_heading level1 col0" >target</th>
#       <th class="col_heading level1 col1" >Count</th>
#       <th class="col_heading level1 col2" >Count Perc</th>
#       <th class="col_heading level1 col3" >Sum</th>
#       <th class="col_heading level1 col4" >Sum Perc</th>
#       <th class="col_heading level1 col5" >housing</th>
#       <th class="col_heading level1 col6" >Count</th>
#       <th class="col_heading level1 col7" >Count Perc</th>
#       <th class="col_heading level1 col8" >Sum</th>
#       <th class="col_heading level1 col9" >Sum Perc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1be71_row0_col0" class="data row0 col0" >good</td>
#       <td id="T_1be71_row0_col1" class="data row0 col1" >700</td>
#       <td id="T_1be71_row0_col2" class="data row0 col2" >70.00%</td>
#       <td id="T_1be71_row0_col3" class="data row0 col3" >2089820.0</td>
#       <td id="T_1be71_row0_col4" class="data row0 col4" >63.88%</td>
#       <td id="T_1be71_row0_col5" class="data row0 col5" >rent</td>
#       <td id="T_1be71_row0_col6" class="data row0 col6" >109</td>
#       <td id="T_1be71_row0_col7" class="data row0 col7" >15.57%</td>
#       <td id="T_1be71_row0_col8" class="data row0 col8" >308150.0</td>
#       <td id="T_1be71_row0_col9" class="data row0 col9" >14.75%</td>
#     </tr>
#     <tr>
#       <td id="T_1be71_row1_col0" class="data row1 col0" ></td>
#       <td id="T_1be71_row1_col1" class="data row1 col1" ></td>
#       <td id="T_1be71_row1_col2" class="data row1 col2" ></td>
#       <td id="T_1be71_row1_col3" class="data row1 col3" ></td>
#       <td id="T_1be71_row1_col4" class="data row1 col4" ></td>
#       <td id="T_1be71_row1_col5" class="data row1 col5" >own</td>
#       <td id="T_1be71_row1_col6" class="data row1 col6" >527</td>
#       <td id="T_1be71_row1_col7" class="data row1 col7" >75.29%</td>
#       <td id="T_1be71_row1_col8" class="data row1 col8" >1495403.0</td>
#       <td id="T_1be71_row1_col9" class="data row1 col9" >71.56%</td>
#     </tr>
#     <tr>
#       <td id="T_1be71_row2_col0" class="data row2 col0" ></td>
#       <td id="T_1be71_row2_col1" class="data row2 col1" ></td>
#       <td id="T_1be71_row2_col2" class="data row2 col2" ></td>
#       <td id="T_1be71_row2_col3" class="data row2 col3" ></td>
#       <td id="T_1be71_row2_col4" class="data row2 col4" ></td>
#       <td id="T_1be71_row2_col5" class="data row2 col5" >for free</td>
#       <td id="T_1be71_row2_col6" class="data row2 col6" >64</td>
#       <td id="T_1be71_row2_col7" class="data row2 col7" >9.14%</td>
#       <td id="T_1be71_row2_col8" class="data row2 col8" >286267.0</td>
#       <td id="T_1be71_row2_col9" class="data row2 col9" >13.70%</td>
#     </tr>
#     <tr>
#       <td id="T_1be71_row3_col0" class="data row3 col0" >bad</td>
#       <td id="T_1be71_row3_col1" class="data row3 col1" >300</td>
#       <td id="T_1be71_row3_col2" class="data row3 col2" >30.00%</td>
#       <td id="T_1be71_row3_col3" class="data row3 col3" >1181438.0</td>
#       <td id="T_1be71_row3_col4" class="data row3 col4" >36.12%</td>
#       <td id="T_1be71_row3_col5" class="data row3 col5" >rent</td>
#       <td id="T_1be71_row3_col6" class="data row3 col6" >70</td>
#       <td id="T_1be71_row3_col7" class="data row3 col7" >23.33%</td>
#       <td id="T_1be71_row3_col8" class="data row3 col8" >250787.0</td>
#       <td id="T_1be71_row3_col9" class="data row3 col9" >21.23%</td>
#     </tr>
#     <tr>
#       <td id="T_1be71_row4_col0" class="data row4 col0" ></td>
#       <td id="T_1be71_row4_col1" class="data row4 col1" ></td>
#       <td id="T_1be71_row4_col2" class="data row4 col2" ></td>
#       <td id="T_1be71_row4_col3" class="data row4 col3" ></td>
#       <td id="T_1be71_row4_col4" class="data row4 col4" ></td>
#       <td id="T_1be71_row4_col5" class="data row4 col5" >own</td>
#       <td id="T_1be71_row4_col6" class="data row4 col6" >186</td>
#       <td id="T_1be71_row4_col7" class="data row4 col7" >62.00%</td>
#       <td id="T_1be71_row4_col8" class="data row4 col8" >687047.0</td>
#       <td id="T_1be71_row4_col9" class="data row4 col9" >58.15%</td>
#     </tr>
#     <tr>
#       <td id="T_1be71_row5_col0" class="data row5 col0" ></td>
#       <td id="T_1be71_row5_col1" class="data row5 col1" ></td>
#       <td id="T_1be71_row5_col2" class="data row5 col2" ></td>
#       <td id="T_1be71_row5_col3" class="data row5 col3" ></td>
#       <td id="T_1be71_row5_col4" class="data row5 col4" ></td>
#       <td id="T_1be71_row5_col5" class="data row5 col5" >for free</td>
#       <td id="T_1be71_row5_col6" class="data row5 col6" >44</td>
#       <td id="T_1be71_row5_col7" class="data row5 col7" >14.67%</td>
#       <td id="T_1be71_row5_col8" class="data row5 col8" >243604.0</td>
#       <td id="T_1be71_row5_col9" class="data row5 col9" >20.62%</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.plotting.scatter_matrix(credit_data, figsize=(20, 20), diagonal="kde")
plt.tight_layout()

# %%
hlp.plot.plot_correlation_heatmap(dataframe=credit_data)

# %% [markdown]
# # Numeric Data

# %%
target_column = 'credit_amount'

# %%
credit_data[target_column].plot.hist(bins=40, figsize=hlp.plot.STANDARD_WIDTH_HEIGHT, title=target_column)
plt.tight_layout()

# %%
credit_data[target_column].hist(by=credit_data['purpose'], bins=30, figsize=(12, 12))
plt.tight_layout()

# %%
# https://seaborn.pydata.org/generated/seaborn.FacetGrid.html
g = sns.FacetGrid(credit_data, col="job",  row="employment",
                  sharex=True,
                  sharey=False,
                  margin_titles=True)
g.map_dataframe(sns.histplot, x=target_column, bins=30)
plt.tight_layout()
sns.set(style='white')

# %%
credit_data[target_column].plot.kde(figsize=hlp.plot.STANDARD_WIDTH_HEIGHT, title=target_column)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=hlp.plot.STANDARD_WIDTH_HEIGHT)

try:
    for label, df in credit_data.groupby('purpose'):
        df[target_column].plot(kind="kde", ax=ax, label=label)

except ValueError:
    pass

plt.title(f'`{target_column}` by `purpose`')
plt.legend()
plt.tight_layout()

# %%
credit_data.plot.scatter(x='duration', y=target_column, figsize=hlp.plot.STANDARD_WIDTH_HEIGHT)
plt.tight_layout()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.set(rc={'figure.figsize': hlp.plot.STANDARD_WIDTH_HEIGHT})
sns.regplot(x='duration', y=target_column, data=credit_data)
plt.tight_layout()

# %%
# https://seaborn.pydata.org/generated/seaborn.lmplot.html
sns.lmplot(x='duration', y=target_column, hue='purpose', data=credit_data, height=10, aspect=hlp.plot.GOLDEN_RATIO)
plt.tight_layout()

# %%
import statsmodels
sns.lmplot(x='duration', y=target_column, hue='purpose', lowess=True, data=credit_data, height=10, aspect=hlp.plot.GOLDEN_RATIO)
plt.tight_layout()

# %%
hlp.pandas.value_frequency(credit_data['installment_commitment'], sort_by_frequency=False)
# Out:
#      Frequency  Percent
# 1.0        136    0.136
# 2.0        231    0.231
# 3.0        157    0.157
# 4.0        476    0.476

# %%
[(x * 2) for x in hlp.plot.STANDARD_WIDTH_HEIGHT]
# Out:
# [20, 12.360679774997093]

# %% [markdown]
# # Categoric Data

# %%
hlp.pandas.value_frequency(credit_data['purpose']).style.bar(vmin=0, subset='Frequency', color=hlp.color.GRAY)
# Out:
# <style type="text/css">
# #T_52ba2_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 100.0%, transparent 100.0%);
# }
# #T_52ba2_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 83.6%, transparent 83.6%);
# }
# #T_52ba2_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 64.6%, transparent 64.6%);
# }
# #T_52ba2_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 36.8%, transparent 36.8%);
# }
# #T_52ba2_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 34.6%, transparent 34.6%);
# }
# #T_52ba2_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 17.9%, transparent 17.9%);
# }
# #T_52ba2_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 7.9%, transparent 7.9%);
# }
# #T_52ba2_row7_col0, #T_52ba2_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 4.3%, transparent 4.3%);
# }
# #T_52ba2_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 3.2%, transparent 3.2%);
# }
# #T_52ba2_row10_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_52ba2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Frequency</th>
#       <th class="col_heading level0 col1" >Percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52ba2_level0_row0" class="row_heading level0 row0" >radio/tv</th>
#       <td id="T_52ba2_row0_col0" class="data row0 col0" >280</td>
#       <td id="T_52ba2_row0_col1" class="data row0 col1" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row1" class="row_heading level0 row1" >new car</th>
#       <td id="T_52ba2_row1_col0" class="data row1 col0" >234</td>
#       <td id="T_52ba2_row1_col1" class="data row1 col1" >0.234000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row2" class="row_heading level0 row2" >furniture/equipment</th>
#       <td id="T_52ba2_row2_col0" class="data row2 col0" >181</td>
#       <td id="T_52ba2_row2_col1" class="data row2 col1" >0.181000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row3" class="row_heading level0 row3" >used car</th>
#       <td id="T_52ba2_row3_col0" class="data row3 col0" >103</td>
#       <td id="T_52ba2_row3_col1" class="data row3 col1" >0.103000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row4" class="row_heading level0 row4" >business</th>
#       <td id="T_52ba2_row4_col0" class="data row4 col0" >97</td>
#       <td id="T_52ba2_row4_col1" class="data row4 col1" >0.097000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row5" class="row_heading level0 row5" >education</th>
#       <td id="T_52ba2_row5_col0" class="data row5 col0" >50</td>
#       <td id="T_52ba2_row5_col1" class="data row5 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row6" class="row_heading level0 row6" >repairs</th>
#       <td id="T_52ba2_row6_col0" class="data row6 col0" >22</td>
#       <td id="T_52ba2_row6_col1" class="data row6 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row7" class="row_heading level0 row7" >domestic appliance</th>
#       <td id="T_52ba2_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_52ba2_row7_col1" class="data row7 col1" >0.012000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row8" class="row_heading level0 row8" >other</th>
#       <td id="T_52ba2_row8_col0" class="data row8 col0" >12</td>
#       <td id="T_52ba2_row8_col1" class="data row8 col1" >0.012000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row9" class="row_heading level0 row9" >retraining</th>
#       <td id="T_52ba2_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_52ba2_row9_col1" class="data row9 col1" >0.009000</td>
#     </tr>
#     <tr>
#       <th id="T_52ba2_level0_row10" class="row_heading level0 row10" >vacation</th>
#       <td id="T_52ba2_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_52ba2_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
hlp.pandas.count_groups(dataframe=credit_data, group_1='purpose', return_style=True)
# Out:
# <style type="text/css">
# #T_04d71_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 23.4%, transparent 23.4%);
# }
# #T_04d71_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 10.3%, transparent 10.3%);
# }
# #T_04d71_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 18.1%, transparent 18.1%);
# }
# #T_04d71_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 28.0%, transparent 28.0%);
# }
# #T_04d71_row4_col2, #T_04d71_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 1.2%, transparent 1.2%);
# }
# #T_04d71_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 2.2%, transparent 2.2%);
# }
# #T_04d71_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 5.0%, transparent 5.0%);
# }
# #T_04d71_row7_col2 {
#   width: 10em;
#   height: 80%;
# }
# #T_04d71_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 0.9%, transparent 0.9%);
# }
# #T_04d71_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 9.7%, transparent 9.7%);
# }
# </style>
# <table id="T_04d71_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" colspan="3">purpose</th>
#     </tr>
#     <tr>
#       <th class="col_heading level1 col0" >purpose</th>
#       <th class="col_heading level1 col1" >Count</th>
#       <th class="col_heading level1 col2" >Count Perc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_04d71_row0_col0" class="data row0 col0" >new car</td>
#       <td id="T_04d71_row0_col1" class="data row0 col1" >234</td>
#       <td id="T_04d71_row0_col2" class="data row0 col2" >23.40%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row1_col0" class="data row1 col0" >used car</td>
#       <td id="T_04d71_row1_col1" class="data row1 col1" >103</td>
#       <td id="T_04d71_row1_col2" class="data row1 col2" >10.30%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row2_col0" class="data row2 col0" >furniture/equipment</td>
#       <td id="T_04d71_row2_col1" class="data row2 col1" >181</td>
#       <td id="T_04d71_row2_col2" class="data row2 col2" >18.10%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row3_col0" class="data row3 col0" >radio/tv</td>
#       <td id="T_04d71_row3_col1" class="data row3 col1" >280</td>
#       <td id="T_04d71_row3_col2" class="data row3 col2" >28.00%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row4_col0" class="data row4 col0" >domestic appliance</td>
#       <td id="T_04d71_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_04d71_row4_col2" class="data row4 col2" >1.20%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row5_col0" class="data row5 col0" >repairs</td>
#       <td id="T_04d71_row5_col1" class="data row5 col1" >22</td>
#       <td id="T_04d71_row5_col2" class="data row5 col2" >2.20%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row6_col0" class="data row6 col0" >education</td>
#       <td id="T_04d71_row6_col1" class="data row6 col1" >50</td>
#       <td id="T_04d71_row6_col2" class="data row6 col2" >5.00%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row7_col0" class="data row7 col0" >vacation</td>
#       <td id="T_04d71_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_04d71_row7_col2" class="data row7 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row8_col0" class="data row8 col0" >retraining</td>
#       <td id="T_04d71_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_04d71_row8_col2" class="data row8 col2" >0.90%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row9_col0" class="data row9 col0" >business</td>
#       <td id="T_04d71_row9_col1" class="data row9 col1" >97</td>
#       <td id="T_04d71_row9_col2" class="data row9 col2" >9.70%</td>
#     </tr>
#     <tr>
#       <td id="T_04d71_row10_col0" class="data row10 col0" >other</td>
#       <td id="T_04d71_row10_col1" class="data row10 col1" >12</td>
#       <td id="T_04d71_row10_col2" class="data row10 col2" >1.20%</td>
#     </tr>
#   </tbody>
# </table>

# %%
hlp.plot.plot_value_frequency(credit_data['purpose'])

# %%
temp = credit_data.groupby(['target', 'job']).agg({'credit_amount': np.mean})
temp.rename({'credit_amount': 'Average Credit Amount'}, axis=1, inplace=True)
temp.style.bar(vmin=0, color=hlp.color.GRAY).format(precision=0)
# Out:
# <style type="text/css">
# #T_89510_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 37.0%, transparent 37.0%);
# }
# #T_89510_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 34.4%, transparent 34.4%);
# }
# #T_89510_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 41.5%, transparent 41.5%);
# }
# #T_89510_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 69.1%, transparent 69.1%);
# }
# #T_89510_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 47.3%, transparent 47.3%);
# }
# #T_89510_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 35.0%, transparent 35.0%);
# }
# #T_89510_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 53.4%, transparent 53.4%);
# }
# #T_89510_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#B4B7B9 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_89510_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Average Credit Amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target</th>
#       <th class="index_name level1" >job</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89510_level0_row0" class="row_heading level0 row0" rowspan="4">good</th>
#       <th id="T_89510_level1_row0" class="row_heading level1 row0" >unemp/unskilled non res</th>
#       <td id="T_89510_row0_col0" class="data row0 col0" >2523</td>
#     </tr>
#     <tr>
#       <th id="T_89510_level1_row1" class="row_heading level1 row1" >unskilled resident</th>
#       <td id="T_89510_row1_col0" class="data row1 col0" >2347</td>
#     </tr>
#     <tr>
#       <th id="T_89510_level1_row2" class="row_heading level1 row2" >skilled</th>
#       <td id="T_89510_row2_col0" class="data row2 col0" >2831</td>
#     </tr>
#     <tr>
#       <th id="T_89510_level1_row3" class="row_heading level1 row3" >high qualif/self emp/mgmt</th>
#       <td id="T_89510_row3_col0" class="data row3 col0" >4709</td>
#     </tr>
#     <tr>
#       <th id="T_89510_level0_row4" class="row_heading level0 row4" rowspan="4">bad</th>
#       <th id="T_89510_level1_row4" class="row_heading level1 row4" >unemp/unskilled non res</th>
#       <td id="T_89510_row4_col0" class="data row4 col0" >3221</td>
#     </tr>
#     <tr>
#       <th id="T_89510_level1_row5" class="row_heading level1 row5" >unskilled resident</th>
#       <td id="T_89510_row5_col0" class="data row5 col0" >2388</td>
#     </tr>
#     <tr>
#       <th id="T_89510_level1_row6" class="row_heading level1 row6" >skilled</th>
#       <td id="T_89510_row6_col0" class="data row6 col0" >3643</td>
#     </tr>
#     <tr>
#       <th id="T_89510_level1_row7" class="row_heading level1 row7" >high qualif/self emp/mgmt</th>
#       <td id="T_89510_row7_col0" class="data row7 col0" >6817</td>
#     </tr>
#   </tbody>
# </table>

# %%
axis = temp.plot.bar(figsize=hlp.plot.STANDARD_WIDTH_HEIGHT, rot=20)
axis.bar_label(axis.containers[0])
plt.tight_layout()

# %%
temp.unstack().round(1)
# Out:
#          Average Credit Amount                             \
# job    unemp/unskilled non res unskilled resident skilled
# target
# good                    2523.0             2347.2  2831.5
# bad                     3221.1             2387.6  3642.7
#
#
# job    high qualif/self emp/mgmt
# target
# good                      4709.3
# bad                       6816.7

# %%
unstacked = temp.unstack()
unstacked.columns = unstacked.columns.droplevel()
unstacked.round(1)
# Out:
# job     unemp/unskilled non res  unskilled resident  skilled  \
# target
# good                     2523.0              2347.2   2831.5
# bad                      3221.1              2387.6   3642.7
#
# job     high qualif/self emp/mgmt
# target
# good                       4709.3
# bad                        6816.7

# %%
axis = unstacked.plot.bar(figsize=hlp.plot.STANDARD_WIDTH_HEIGHT, rot=20)
for container in axis.containers:
    axis.bar_label(container)
plt.tight_layout()

# %%
hlp.plot.plot_dodged_barchart(dataframe=credit_data, outer_column='target', inner_column='credit_history')

# %%
hlp.plot.plot_histogram_with_categorical(dataframe=credit_data, numeric_column='credit_amount', categorical_column='target')

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Monthly Count

# %%
flights_5k = data.flights_5k()

# %%
flights_5k['date_month'] = hlp.date.floor(flights_5k['date'], granularity=hlp.date.Granularity.MONTH)

# %%
flights_5k['origin_top_5'] = hlp.pandas.top_n_categories(categorical=flights_5k['origin'])

# %%
flights_5k.head()
# Out:
#                  date  delay  distance origin destination  date_month  \
# 0 2001-01-10 18:20:00     25       192    SAT         HOU  2001-01-01
# 1 2001-01-31 16:45:00     17       371    SNA         OAK  2001-01-01
# 2 2001-02-16 12:07:00     21       417    SJC         SAN  2001-02-01
# 3 2001-02-03 17:00:00     -5       480    SMF         SAN  2001-02-01
# 4 2001-01-02 12:16:00      5       833    OKC         PHX  2001-01-01
#
#   origin_top_5
# 0        Other
# 1        Other
# 2        Other
# 3        Other
# 4        Other

# %%
per_month_per_origin = flights_5k.groupby(['date_month', 'origin_top_5']).size()
per_month_per_origin.head(10)
# Out:
# date_month  origin_top_5
# 2001-01-01  LAS              112
#             PHX               95
#             HOU               95
#             DAL               78
#             BWI               79
#             Other           1201
# 2001-02-01  LAS               99
#             PHX               97
#             HOU               74
#             DAL               75
# dtype: int64

# %%
import matplotlib.dates as mdates
ax = pd.DataFrame(np.log10(per_month_per_origin)).unstack().plot(figsize=(9, 6))
ax.xaxis.set_major_locator(mdates.MonthLocator())

# %%
hlp.plot.plot_dodged_barchart(dataframe=flights_5k, outer_column='date_month', inner_column='origin_top_5')
